# %%
import sys
sys.path.append('../input/iterative-stratification/iterative-stratification-master')
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import log_loss
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import warnings
warnings.filterwarnings('ignore')

# %%
train_features = pd.read_csv('../input/lish-moa/train_features.csv')
train_targets = pd.read_csv('../input/lish-moa/train_targets_scored.csv')
test_features = pd.read_csv('../input/lish-moa/test_features.csv')

ss = pd.read_csv('../input/lish-moa/sample_submission.csv')

# %%
def preprocess(df):
    df = df.copy()
    df.loc[:, 'cp_type'] = df.loc[:, 'cp_type'].map({'trt_cp': 0, 
                                                   'ctl_vehicle': 1})
    df.loc[:, 'cp_dose'] = df.loc[:, 'cp_dose'].map({'D1': 0, 'D2': 1})
    df = df.drop(columns='sig_id')
    return df


train_features = preprocess(train_features)
test_features = preprocess(test_features)

# Delete objects without MoA. They has ctl_vehicle == 1 and they are cacb2b860 drug
train_targets = train_targets.loc[train_features['cp_type'] == 0].reset_index(drop=True)
train_features = train_features.loc[train_features['cp_type'] == 0].reset_index(drop=True)
train_targets = train_targets.drop(columns='sig_id')
train_features.head()
# Out:
#    cp_type  cp_time  cp_dose     g-0     g-1     g-2     g-3     g-4     g-5  \
# 0        0       24        0  1.0620  0.5577 -0.2479 -0.6208 -0.1944 -1.0120
# 1        0       72        0  0.0743  0.4087  0.2991  0.0604  1.0190  0.5207
# 2        0       48        0  0.6280  0.5817  1.5540 -0.0764 -0.0323  1.2390
# 3        0       48        0 -0.5138 -0.2491 -0.2656  0.5288  4.0620 -0.8095
# 4        0       72        1 -0.3254 -0.4009  0.9700  0.6919  1.4180 -0.8244
#
#       g-6  ...    c-90    c-91    c-92    c-93    c-94    c-95    c-96  \
# 0 -1.0220  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584 -0.3981
# 1  0.2341  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899  0.1522
# 2  0.1715  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174 -0.6417
# 3 -1.9590  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880 -1.6210
# 4 -0.2800  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031  0.1094
#
#      c-97    c-98    c-99
# 0  0.2139  0.3801  0.4176
# 1  0.1241  0.6077  0.7371
# 2 -0.2187 -1.4080  0.6931
# 3 -0.8784 -0.3876 -0.8154
# 4  0.2885 -0.3786  0.7125
#
# [5 rows x 875 columns]

# %%
from sklearn.feature_selection import VarianceThreshold

features_np = train_features.to_numpy()
vt_selector = VarianceThreshold(threshold=0.8)
vt_selector.fit(features_np[:, 3:])
_top_feats = vt_selector.get_support(indices=True)
_top_feats = _top_feats + 3
_f = np.array([1, 2])
_top_feats = np.copy(np.concatenate([_f, _top_feats]))
del _f
top_feats = _top_feats.tolist()  # !
del _top_feats

print(len(top_feats))
print(top_feats[:5], '…', top_feats[-5:])
del features_np
# Out:
# 809
# [1, 2, 3, 5, 6] … [870, 871, 872, 873, 874]

# %%
def create_folds(num_starts, num_splits):
    
    folds = []
    
    # LOAD FILES
    train_feats = pd.read_csv('../input/lish-moa/train_features.csv')
    scored = pd.read_csv('/kaggle/input/lish-moa/train_targets_scored.csv')
    drug = pd.read_csv('/kaggle/input/lish-moa/train_drug.csv')
    scored = scored.loc[train_feats['cp_type'] == 'trt_cp', :]
    drug = drug.loc[train_feats['cp_type'] == 'trt_cp', :]
    targets = scored.columns[1:]
    scored = scored.merge(drug, on='sig_id', how='left') 

    # LOCATE DRUGS
    vc = scored.drug_id.value_counts()
    vc1 = vc.loc[vc <= 18].index.sort_values()
    vc2 = vc.loc[vc > 18].index.sort_values()
    
    for seed in range(num_starts):

        # STRATIFY DRUGS 18X OR LESS
        dct1 = {}; dct2 = {}
        skf = MultilabelStratifiedKFold(n_splits=num_splits, shuffle=True, random_state=seed)
        tmp = scored.groupby('drug_id')[targets].mean().loc[vc1]
        for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[targets])):
            dd = {k:fold for k in tmp.index[idxV].values}
            dct1.update(dd)

        # STRATIFY DRUGS MORE THAN 18X
        skf = MultilabelStratifiedKFold(n_splits=num_splits, shuffle=True, random_state=seed)
        tmp = scored.loc[scored.drug_id.isin(vc2)].reset_index(drop=True)
        for fold,(idxT,idxV) in enumerate(skf.split(tmp,tmp[targets])):
            dd = {k:fold for k in tmp.sig_id[idxV].values}
            dct2.update(dd)

        # ASSIGN FOLDS
        scored['fold'] = scored.drug_id.map(dct1)
        scored.loc[scored.fold.isna(),'fold'] =\
            scored.loc[scored.fold.isna(),'sig_id'].map(dct2)
        scored.fold = scored.fold.astype('int8')
        folds.append(scored.fold.values)
        
        del scored['fold']
        
    return np.stack(folds)

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)

# %%
N_FOLDS = 6
N_STARTS = 5
N_EPOCHS = 50
random_state = 42

batch_size = 128
val_batch_size = batch_size * 4

ntargets = train_targets.shape[1]
targets = [col for col in train_targets.columns]

criterion = nn.BCELoss()  # Binary Cross Entropy loss function

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class MoaModel(nn.Module):
    def __init__(self, num_columns):
        super(MoaModel, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, 1048))
        
        self.batch_norm2 = nn.BatchNorm1d(1048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(1048, 1048))
        
        self.batch_norm3 = nn.BatchNorm1d(1048)
        self.dropout3 = nn.Dropout(0.5)
        self.dense3 = nn.utils.weight_norm(nn.Linear(1048, 206))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.sigmoid(self.dense3(x))
        
        return x

# %%
# dataset class
class MoaDataset(Dataset):
    def __init__(self, df, targets, feats_idx, mode='train'):
        self.mode = mode
        self.feats = feats_idx
        self.data = df[:, feats_idx]
        if mode=='train':
            self.targets = targets
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            return torch.FloatTensor(self.data[idx]), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'test':
            return torch.FloatTensor(self.data[idx]), 0

# %%
folds_cv = create_folds(N_STARTS, N_FOLDS)

unique, counts = np.unique(folds_cv[0], return_counts=True)
for i in unique:
    print(i, counts[i])
del unique
del counts
# Out:
# 0 3648
# 1 3707
# 2 3602
# 3 3640
# 4 3677
# 5 3674

# %%
for seed in range(N_STARTS):
    print(f'Train seed {seed}')
    set_seed(seed)

    for fold in range(N_FOLDS):
        tr_idx = folds_cv[seed] != fold
        te_idx = folds_cv[seed] == fold

        xtrain = train_features.to_numpy()[tr_idx]
        ytrain = train_targets.to_numpy()[tr_idx]
        xval = train_features.to_numpy()[te_idx]
        yval = train_targets.to_numpy()[te_idx]

        train_set = MoaDataset(xtrain, ytrain, top_feats)
        val_set = MoaDataset(xval, yval, top_feats)
        
        dataloaders = {
            'train': DataLoader(train_set, batch_size=batch_size, shuffle=True),
            'val': DataLoader(val_set, batch_size=val_batch_size, shuffle=False)
        }

        model = MoaModel(len(top_feats)).to(device)
        checkpoint_path = f'repeat:{seed}_Fold:{fold+1}.pt'
        optimizer = optim.Adam(model.parameters(), weight_decay=1e-5)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', 
                                                         factor=0.1, patience=3, 
                                                         eps=1e-4, verbose=True)
        best_loss = {'train': np.inf, 'val': np.inf}
            
        for epoch in range(N_EPOCHS):
            epoch_loss = {'train': 0.0, 'val': 0.0}
          
            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()
                else:
                    model.eval()
                
                running_loss = 0.0
                
                for i, (x, y) in enumerate(dataloaders[phase]):
                    x, y = x.to(device), y.to(device)
                    
                    optimizer.zero_grad()
                    
                    with torch.set_grad_enabled(phase=='train'):
                        preds = model(x)
                        loss = criterion(preds, y)
                        
                        if phase=='train':
                            loss.backward()
                            optimizer.step()
                        
                    running_loss += loss.item() / len(dataloaders[phase])
                
                epoch_loss[phase] = running_loss
            
            print("Epoch {}/{}   -   loss: {:5.5f}   -   val_loss: {:5.5f}".format(epoch+1, N_EPOCHS, epoch_loss['train'], epoch_loss['val']))
            
            scheduler.step(epoch_loss['val'])
            
            if epoch_loss['val'] < best_loss['val']:
                best_loss = epoch_loss
                torch.save(model.state_dict(), checkpoint_path)
# Out:
# Train seed 0
# Epoch 1/50   -   loss: 0.37683   -   val_loss: 0.07012
# Epoch 2/50   -   loss: 0.04351   -   val_loss: 0.02685
# Epoch 3/50   -   loss: 0.02600   -   val_loss: 0.02094
# Epoch 4/50   -   loss: 0.02238   -   val_loss: 0.02008
# Epoch 5/50   -   loss: 0.02091   -   val_loss: 0.01881
# Epoch 6/50   -   loss: 0.01983   -   val_loss: 0.01836
# Epoch 7/50   -   loss: 0.01927   -   val_loss: 0.01802
# Epoch 8/50   -   loss: 0.01908   -   val_loss: 0.01776
# Epoch 9/50   -   loss: 0.01820   -   val_loss: 0.01773
# Epoch 10/50   -   loss: 0.01805   -   val_loss: 0.01739
# Epoch 11/50   -   loss: 0.01766   -   val_loss: 0.01721
# Epoch 12/50   -   loss: 0.01733   -   val_loss: 0.01705
# Epoch 13/50   -   loss: 0.01702   -   val_loss: 0.01702
# Epoch 14/50   -   loss: 0.01669   -   val_loss: 0.01691
# Epoch 15/50   -   loss: 0.01665   -   val_loss: 0.01714
# Epoch 16/50   -   loss: 0.01650   -   val_loss: 0.01678
# Epoch 17/50   -   loss: 0.01627   -   val_loss: 0.01684
# Epoch 18/50   -   loss: 0.01601   -   val_loss: 0.01681
# Epoch 19/50   -   loss: 0.01571   -   val_loss: 0.01686
# Epoch 20/50   -   loss: 0.01565   -   val_loss: 0.01672
# Epoch 21/50   -   loss: 0.01544   -   val_loss: 0.01684
# Epoch 22/50   -   loss: 0.01527   -   val_loss: 0.01676
# Epoch 23/50   -   loss: 0.01518   -   val_loss: 0.01682
# Epoch 24/50   -   loss: 0.01498   -   val_loss: 0.01677
# Epoch    24: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 25/50   -   loss: 0.01429   -   val_loss: 0.01665
# Epoch 26/50   -   loss: 0.01399   -   val_loss: 0.01666
# Epoch 27/50   -   loss: 0.01380   -   val_loss: 0.01664
# Epoch 28/50   -   loss: 0.01371   -   val_loss: 0.01668
# Epoch 29/50   -   loss: 0.01355   -   val_loss: 0.01670
# Epoch 30/50   -   loss: 0.01346   -   val_loss: 0.01669
# Epoch 31/50   -   loss: 0.01333   -   val_loss: 0.01672
# Epoch 32/50   -   loss: 0.01317   -   val_loss: 0.01674
# Epoch 33/50   -   loss: 0.01308   -   val_loss: 0.01676
# Epoch 34/50   -   loss: 0.01293   -   val_loss: 0.01677
# Epoch 35/50   -   loss: 0.01281   -   val_loss: 0.01679
# Epoch 36/50   -   loss: 0.01280   -   val_loss: 0.01676
# Epoch 37/50   -   loss: 0.01258   -   val_loss: 0.01683
# Epoch 38/50   -   loss: 0.01258   -   val_loss: 0.01683
# Epoch 39/50   -   loss: 0.01243   -   val_loss: 0.01686
# Epoch 40/50   -   loss: 0.01240   -   val_loss: 0.01688
# Epoch 41/50   -   loss: 0.01226   -   val_loss: 0.01689
# Epoch 42/50   -   loss: 0.01212   -   val_loss: 0.01688
# Epoch 43/50   -   loss: 0.01207   -   val_loss: 0.01690
# Epoch 44/50   -   loss: 0.01198   -   val_loss: 0.01692
# Epoch 45/50   -   loss: 0.01186   -   val_loss: 0.01691
# Epoch 46/50   -   loss: 0.01178   -   val_loss: 0.01693
# Epoch 47/50   -   loss: 0.01161   -   val_loss: 0.01697
# Epoch 48/50   -   loss: 0.01160   -   val_loss: 0.01696
# Epoch 49/50   -   loss: 0.01146   -   val_loss: 0.01699
# Epoch 50/50   -   loss: 0.01132   -   val_loss: 0.01702
# Epoch 1/50   -   loss: 0.37757   -   val_loss: 0.06779
# Epoch 2/50   -   loss: 0.04252   -   val_loss: 0.02801
# Epoch 3/50   -   loss: 0.02578   -   val_loss: 0.02260
# Epoch 4/50   -   loss: 0.02218   -   val_loss: 0.02113
# Epoch 5/50   -   loss: 0.02069   -   val_loss: 0.02019
# Epoch 6/50   -   loss: 0.02012   -   val_loss: 0.02016
# Epoch 7/50   -   loss: 0.01915   -   val_loss: 0.01942
# Epoch 8/50   -   loss: 0.01852   -   val_loss: 0.01912
# Epoch 9/50   -   loss: 0.01814   -   val_loss: 0.01892
# Epoch 10/50   -   loss: 0.01774   -   val_loss: 0.01880
# Epoch 11/50   -   loss: 0.01745   -   val_loss: 0.01860
# Epoch 12/50   -   loss: 0.01714   -   val_loss: 0.01856
# Epoch 13/50   -   loss: 0.01681   -   val_loss: 0.01850
# Epoch 14/50   -   loss: 0.01657   -   val_loss: 0.01849
# Epoch 15/50   -   loss: 0.01631   -   val_loss: 0.01834
# Epoch 16/50   -   loss: 0.01607   -   val_loss: 0.01845
# Epoch 17/50   -   loss: 0.01596   -   val_loss: 0.01844
# Epoch 18/50   -   loss: 0.01583   -   val_loss: 0.01856
# Epoch 19/50   -   loss: 0.01556   -   val_loss: 0.01842
# Epoch    19: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 20/50   -   loss: 0.01488   -   val_loss: 0.01828
# Epoch 21/50   -   loss: 0.01471   -   val_loss: 0.01825
# Epoch 22/50   -   loss: 0.01457   -   val_loss: 0.01827
# Epoch 23/50   -   loss: 0.01441   -   val_loss: 0.01827
# Epoch 24/50   -   loss: 0.01427   -   val_loss: 0.01828
# Epoch 25/50   -   loss: 0.01416   -   val_loss: 0.01831
# Epoch 26/50   -   loss: 0.01408   -   val_loss: 0.01829
# Epoch 27/50   -   loss: 0.01397   -   val_loss: 0.01831
# Epoch 28/50   -   loss: 0.01389   -   val_loss: 0.01834
# Epoch 29/50   -   loss: 0.01386   -   val_loss: 0.01833
# Epoch 30/50   -   loss: 0.01369   -   val_loss: 0.01838
# Epoch 31/50   -   loss: 0.01362   -   val_loss: 0.01836
# Epoch 32/50   -   loss: 0.01352   -   val_loss: 0.01839
# Epoch 33/50   -   loss: 0.01338   -   val_loss: 0.01842
# Epoch 34/50   -   loss: 0.01333   -   val_loss: 0.01843
# Epoch 35/50   -   loss: 0.01321   -   val_loss: 0.01845
# Epoch 36/50   -   loss: 0.01309   -   val_loss: 0.01849
# Epoch 37/50   -   loss: 0.01300   -   val_loss: 0.01848
# Epoch 38/50   -   loss: 0.01294   -   val_loss: 0.01848
# Epoch 39/50   -   loss: 0.01281   -   val_loss: 0.01850
# Epoch 40/50   -   loss: 0.01269   -   val_loss: 0.01852
# Epoch 41/50   -   loss: 0.01256   -   val_loss: 0.01852
# Epoch 42/50   -   loss: 0.01246   -   val_loss: 0.01856
# Epoch 43/50   -   loss: 0.01236   -   val_loss: 0.01856
# Epoch 44/50   -   loss: 0.01223   -   val_loss: 0.01859
# Epoch 45/50   -   loss: 0.01213   -   val_loss: 0.01861
# Epoch 46/50   -   loss: 0.01202   -   val_loss: 0.01861
# Epoch 47/50   -   loss: 0.01193   -   val_loss: 0.01860
# Epoch 48/50   -   loss: 0.01180   -   val_loss: 0.01863
# Epoch 49/50   -   loss: 0.01165   -   val_loss: 0.01867
# Epoch 50/50   -   loss: 0.01159   -   val_loss: 0.01866
# Epoch 1/50   -   loss: 0.37750   -   val_loss: 0.05978
# Epoch 2/50   -   loss: 0.04229   -   val_loss: 0.02698
# Epoch 3/50   -   loss: 0.02586   -   val_loss: 0.02192
# Epoch 4/50   -   loss: 0.02199   -   val_loss: 0.02047
# Epoch 5/50   -   loss: 0.02075   -   val_loss: 0.01946
# Epoch 6/50   -   loss: 0.01981   -   val_loss: 0.01868
# Epoch 7/50   -   loss: 0.01930   -   val_loss: 0.01828
# Epoch 8/50   -   loss: 0.01880   -   val_loss: 0.01789
# Epoch 9/50   -   loss: 0.01833   -   val_loss: 0.01785
# Epoch 10/50   -   loss: 0.01787   -   val_loss: 0.01772
# Epoch 11/50   -   loss: 0.01797   -   val_loss: 0.01749
# Epoch 12/50   -   loss: 0.01742   -   val_loss: 0.01759
# Epoch 13/50   -   loss: 0.01705   -   val_loss: 0.01730
# Epoch 14/50   -   loss: 0.01674   -   val_loss: 0.01733
# Epoch 15/50   -   loss: 0.01648   -   val_loss: 0.01727
# Epoch 16/50   -   loss: 0.01624   -   val_loss: 0.01717
# Epoch 17/50   -   loss: 0.01608   -   val_loss: 0.01716
# Epoch 18/50   -   loss: 0.01581   -   val_loss: 0.01727
# Epoch 19/50   -   loss: 0.01558   -   val_loss: 0.01727
# Epoch 20/50   -   loss: 0.01538   -   val_loss: 0.01728
# Epoch 21/50   -   loss: 0.01534   -   val_loss: 0.01715
# Epoch 22/50   -   loss: 0.01521   -   val_loss: 0.01713
# Epoch 23/50   -   loss: 0.01508   -   val_loss: 0.01718
# Epoch 24/50   -   loss: 0.01495   -   val_loss: 0.01710
# Epoch 25/50   -   loss: 0.01484   -   val_loss: 0.01729
# Epoch 26/50   -   loss: 0.01472   -   val_loss: 0.01724
# Epoch 27/50   -   loss: 0.01453   -   val_loss: 0.01727
# Epoch 28/50   -   loss: 0.01453   -   val_loss: 0.01735
# Epoch    28: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 29/50   -   loss: 0.01371   -   val_loss: 0.01713
# Epoch 30/50   -   loss: 0.01343   -   val_loss: 0.01710
# Epoch 31/50   -   loss: 0.01327   -   val_loss: 0.01710
# Epoch 32/50   -   loss: 0.01313   -   val_loss: 0.01710
# Epoch 33/50   -   loss: 0.01291   -   val_loss: 0.01711
# Epoch 34/50   -   loss: 0.01279   -   val_loss: 0.01714
# Epoch 35/50   -   loss: 0.01272   -   val_loss: 0.01714
# Epoch 36/50   -   loss: 0.01257   -   val_loss: 0.01713
# Epoch 37/50   -   loss: 0.01248   -   val_loss: 0.01716
# Epoch 38/50   -   loss: 0.01235   -   val_loss: 0.01720
# Epoch 39/50   -   loss: 0.01226   -   val_loss: 0.01722
# Epoch 40/50   -   loss: 0.01215   -   val_loss: 0.01723
# Epoch 41/50   -   loss: 0.01197   -   val_loss: 0.01730
# Epoch 42/50   -   loss: 0.01195   -   val_loss: 0.01730
# Epoch 43/50   -   loss: 0.01181   -   val_loss: 0.01730
# Epoch 44/50   -   loss: 0.01170   -   val_loss: 0.01734
# Epoch 45/50   -   loss: 0.01164   -   val_loss: 0.01735
# Epoch 46/50   -   loss: 0.01149   -   val_loss: 0.01738
# Epoch 47/50   -   loss: 0.01142   -   val_loss: 0.01737
# Epoch 48/50   -   loss: 0.01137   -   val_loss: 0.01742
# Epoch 49/50   -   loss: 0.01127   -   val_loss: 0.01747
# Epoch 50/50   -   loss: 0.01114   -   val_loss: 0.01748
# Epoch 1/50   -   loss: 0.37916   -   val_loss: 0.07102
# Epoch 2/50   -   loss: 0.04299   -   val_loss: 0.02635
# Epoch 3/50   -   loss: 0.02558   -   val_loss: 0.02261
# Epoch 4/50   -   loss: 0.02217   -   val_loss: 0.02059
# Epoch 5/50   -   loss: 0.02078   -   val_loss: 0.02039
# Epoch 6/50   -   loss: 0.01996   -   val_loss: 0.01944
# Epoch 7/50   -   loss: 0.01933   -   val_loss: 0.01936
# Epoch 8/50   -   loss: 0.01905   -   val_loss: 0.01863
# Epoch 9/50   -   loss: 0.01859   -   val_loss: 0.01836
# Epoch 10/50   -   loss: 0.01845   -   val_loss: 0.01853
# Epoch 11/50   -   loss: 0.01799   -   val_loss: 0.01850
# Epoch 12/50   -   loss: 0.01744   -   val_loss: 0.01797
# Epoch 13/50   -   loss: 0.01728   -   val_loss: 0.01780
# Epoch 14/50   -   loss: 0.01705   -   val_loss: 0.01769
# Epoch 15/50   -   loss: 0.01674   -   val_loss: 0.01780
# Epoch 16/50   -   loss: 0.01653   -   val_loss: 0.01761
# Epoch 17/50   -   loss: 0.01646   -   val_loss: 0.01763
# Epoch 18/50   -   loss: 0.01632   -   val_loss: 0.01759
# Epoch 19/50   -   loss: 0.01599   -   val_loss: 0.01747
# Epoch 20/50   -   loss: 0.01592   -   val_loss: 0.01752
# Epoch 21/50   -   loss: 0.01569   -   val_loss: 0.01743
# Epoch 22/50   -   loss: 0.01561   -   val_loss: 0.01743
# Epoch 23/50   -   loss: 0.01541   -   val_loss: 0.01751
# Epoch 24/50   -   loss: 0.01537   -   val_loss: 0.01746
# Epoch 25/50   -   loss: 0.01538   -   val_loss: 0.01740
# Epoch 26/50   -   loss: 0.01522   -   val_loss: 0.01740
# Epoch 27/50   -   loss: 0.01513   -   val_loss: 0.01740
# Epoch 28/50   -   loss: 0.01506   -   val_loss: 0.01744
# Epoch 29/50   -   loss: 0.01497   -   val_loss: 0.01748
# Epoch 30/50   -   loss: 0.01490   -   val_loss: 0.01736
# Epoch 31/50   -   loss: 0.01479   -   val_loss: 0.01744
# Epoch 32/50   -   loss: 0.01475   -   val_loss: 0.01729
# Epoch 33/50   -   loss: 0.01480   -   val_loss: 0.01760
# Epoch 34/50   -   loss: 0.01482   -   val_loss: 0.01751
# Epoch 35/50   -   loss: 0.01465   -   val_loss: 0.01745
# Epoch 36/50   -   loss: 0.01459   -   val_loss: 0.01746
# Epoch    36: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 37/50   -   loss: 0.01393   -   val_loss: 0.01732
# Epoch 38/50   -   loss: 0.01363   -   val_loss: 0.01729
# Epoch 39/50   -   loss: 0.01349   -   val_loss: 0.01730
# Epoch 40/50   -   loss: 0.01316   -   val_loss: 0.01727
# Epoch 41/50   -   loss: 0.01323   -   val_loss: 0.01730
# Epoch 42/50   -   loss: 0.01309   -   val_loss: 0.01732
# Epoch 43/50   -   loss: 0.01315   -   val_loss: 0.01729
# Epoch 44/50   -   loss: 0.01287   -   val_loss: 0.01740
# Epoch 45/50   -   loss: 0.01285   -   val_loss: 0.01735
# Epoch 46/50   -   loss: 0.01269   -   val_loss: 0.01736
# Epoch 47/50   -   loss: 0.01251   -   val_loss: 0.01743
# Epoch 48/50   -   loss: 0.01241   -   val_loss: 0.01742
# Epoch 49/50   -   loss: 0.01238   -   val_loss: 0.01742
# Epoch 50/50   -   loss: 0.01233   -   val_loss: 0.01753
# Epoch 1/50   -   loss: 0.37737   -   val_loss: 0.06149
# Epoch 2/50   -   loss: 0.04285   -   val_loss: 0.02611
# Epoch 3/50   -   loss: 0.02583   -   val_loss: 0.02172
# Epoch 4/50   -   loss: 0.02221   -   val_loss: 0.02012
# Epoch 5/50   -   loss: 0.02085   -   val_loss: 0.01944
# Epoch 6/50   -   loss: 0.01988   -   val_loss: 0.01871
# Epoch 7/50   -   loss: 0.01926   -   val_loss: 0.01826
# Epoch 8/50   -   loss: 0.01860   -   val_loss: 0.01797
# Epoch 9/50   -   loss: 0.01825   -   val_loss: 0.01779
# Epoch 10/50   -   loss: 0.01787   -   val_loss: 0.01751
# Epoch 11/50   -   loss: 0.01751   -   val_loss: 0.01737
# Epoch 12/50   -   loss: 0.01717   -   val_loss: 0.01730
# Epoch 13/50   -   loss: 0.01694   -   val_loss: 0.01730
# Epoch 14/50   -   loss: 0.01684   -   val_loss: 0.01723
# Epoch 15/50   -   loss: 0.01641   -   val_loss: 0.01708
# Epoch 16/50   -   loss: 0.01621   -   val_loss: 0.01716
# Epoch 17/50   -   loss: 0.01605   -   val_loss: 0.01713
# Epoch 18/50   -   loss: 0.01579   -   val_loss: 0.01701
# Epoch 19/50   -   loss: 0.01556   -   val_loss: 0.01705
# Epoch 20/50   -   loss: 0.01544   -   val_loss: 0.01702
# Epoch 21/50   -   loss: 0.01527   -   val_loss: 0.01711
# Epoch 22/50   -   loss: 0.01508   -   val_loss: 0.01721
# Epoch    22: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 23/50   -   loss: 0.01438   -   val_loss: 0.01692
# Epoch 24/50   -   loss: 0.01410   -   val_loss: 0.01692
# Epoch 25/50   -   loss: 0.01393   -   val_loss: 0.01693
# Epoch 26/50   -   loss: 0.01374   -   val_loss: 0.01693
# Epoch 27/50   -   loss: 0.01367   -   val_loss: 0.01696
# Epoch 28/50   -   loss: 0.01358   -   val_loss: 0.01698
# Epoch 29/50   -   loss: 0.01342   -   val_loss: 0.01701
# Epoch 30/50   -   loss: 0.01326   -   val_loss: 0.01700
# Epoch 31/50   -   loss: 0.01318   -   val_loss: 0.01704
# Epoch 32/50   -   loss: 0.01308   -   val_loss: 0.01704
# Epoch 33/50   -   loss: 0.01290   -   val_loss: 0.01708
# Epoch 34/50   -   loss: 0.01288   -   val_loss: 0.01710
# Epoch 35/50   -   loss: 0.01271   -   val_loss: 0.01710
# Epoch 36/50   -   loss: 0.01264   -   val_loss: 0.01713
# Epoch 37/50   -   loss: 0.01250   -   val_loss: 0.01714
# Epoch 38/50   -   loss: 0.01246   -   val_loss: 0.01719
# Epoch 39/50   -   loss: 0.01230   -   val_loss: 0.01717
# Epoch 40/50   -   loss: 0.01219   -   val_loss: 0.01719
# Epoch 41/50   -   loss: 0.01207   -   val_loss: 0.01724
# Epoch 42/50   -   loss: 0.01202   -   val_loss: 0.01726
# Epoch 43/50   -   loss: 0.01188   -   val_loss: 0.01728
# Epoch 44/50   -   loss: 0.01177   -   val_loss: 0.01727
# Epoch 45/50   -   loss: 0.01167   -   val_loss: 0.01737
# Epoch 46/50   -   loss: 0.01157   -   val_loss: 0.01732
# Epoch 47/50   -   loss: 0.01138   -   val_loss: 0.01734
# Epoch 48/50   -   loss: 0.01129   -   val_loss: 0.01738
# Epoch 49/50   -   loss: 0.01121   -   val_loss: 0.01739
# Epoch 50/50   -   loss: 0.01116   -   val_loss: 0.01742
# Epoch 1/50   -   loss: 0.37956   -   val_loss: 0.06696
# Epoch 2/50   -   loss: 0.04270   -   val_loss: 0.02777
# Epoch 3/50   -   loss: 0.02573   -   val_loss: 0.02243
# Epoch 4/50   -   loss: 0.02221   -   val_loss: 0.02029
# Epoch 5/50   -   loss: 0.02077   -   val_loss: 0.01959
# Epoch 6/50   -   loss: 0.01983   -   val_loss: 0.01891
# Epoch 7/50   -   loss: 0.01907   -   val_loss: 0.01850
# Epoch 8/50   -   loss: 0.01867   -   val_loss: 0.01819
# Epoch 9/50   -   loss: 0.01816   -   val_loss: 0.01791
# Epoch 10/50   -   loss: 0.01783   -   val_loss: 0.01810
# Epoch 11/50   -   loss: 0.01786   -   val_loss: 0.01768
# Epoch 12/50   -   loss: 0.01755   -   val_loss: 0.01779
# Epoch 13/50   -   loss: 0.01715   -   val_loss: 0.01742
# Epoch 14/50   -   loss: 0.01680   -   val_loss: 0.01734
# Epoch 15/50   -   loss: 0.01649   -   val_loss: 0.01719
# Epoch 16/50   -   loss: 0.01630   -   val_loss: 0.01718
# Epoch 17/50   -   loss: 0.01607   -   val_loss: 0.01716
# Epoch 18/50   -   loss: 0.01576   -   val_loss: 0.01711
# Epoch 19/50   -   loss: 0.01564   -   val_loss: 0.01708
# Epoch 20/50   -   loss: 0.01538   -   val_loss: 0.01716
# Epoch 21/50   -   loss: 0.01536   -   val_loss: 0.01717
# Epoch 22/50   -   loss: 0.01514   -   val_loss: 0.01716
# Epoch 23/50   -   loss: 0.01495   -   val_loss: 0.01713
# Epoch    23: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 24/50   -   loss: 0.01428   -   val_loss: 0.01697
# Epoch 25/50   -   loss: 0.01398   -   val_loss: 0.01694
# Epoch 26/50   -   loss: 0.01386   -   val_loss: 0.01693
# Epoch 27/50   -   loss: 0.01363   -   val_loss: 0.01695
# Epoch 28/50   -   loss: 0.01350   -   val_loss: 0.01693
# Epoch 29/50   -   loss: 0.01340   -   val_loss: 0.01695
# Epoch 30/50   -   loss: 0.01327   -   val_loss: 0.01697
# Epoch 31/50   -   loss: 0.01315   -   val_loss: 0.01697
# Epoch 32/50   -   loss: 0.01304   -   val_loss: 0.01698
# Epoch 33/50   -   loss: 0.01293   -   val_loss: 0.01704
# Epoch 34/50   -   loss: 0.01284   -   val_loss: 0.01701
# Epoch 35/50   -   loss: 0.01271   -   val_loss: 0.01706
# Epoch 36/50   -   loss: 0.01261   -   val_loss: 0.01705
# Epoch 37/50   -   loss: 0.01251   -   val_loss: 0.01708
# Epoch 38/50   -   loss: 0.01238   -   val_loss: 0.01708
# Epoch 39/50   -   loss: 0.01227   -   val_loss: 0.01712
# Epoch 40/50   -   loss: 0.01219   -   val_loss: 0.01712
# Epoch 41/50   -   loss: 0.01205   -   val_loss: 0.01715
# Epoch 42/50   -   loss: 0.01199   -   val_loss: 0.01716
# Epoch 43/50   -   loss: 0.01189   -   val_loss: 0.01717
# Epoch 44/50   -   loss: 0.01175   -   val_loss: 0.01718
# Epoch 45/50   -   loss: 0.01169   -   val_loss: 0.01724
# Epoch 46/50   -   loss: 0.01148   -   val_loss: 0.01721
# Epoch 47/50   -   loss: 0.01144   -   val_loss: 0.01726
# Epoch 48/50   -   loss: 0.01130   -   val_loss: 0.01727
# Epoch 49/50   -   loss: 0.01120   -   val_loss: 0.01726
# Epoch 50/50   -   loss: 0.01106   -   val_loss: 0.01733
# Train seed 1
# Epoch 1/50   -   loss: 0.37884   -   val_loss: 0.06459
# Epoch 2/50   -   loss: 0.04277   -   val_loss: 0.02625
# Epoch 3/50   -   loss: 0.02588   -   val_loss: 0.02205
# Epoch 4/50   -   loss: 0.02239   -   val_loss: 0.02055
# Epoch 5/50   -   loss: 0.02070   -   val_loss: 0.01930
# Epoch 6/50   -   loss: 0.01977   -   val_loss: 0.01889
# Epoch 7/50   -   loss: 0.01916   -   val_loss: 0.01835
# Epoch 8/50   -   loss: 0.01862   -   val_loss: 0.01823
# Epoch 9/50   -   loss: 0.01819   -   val_loss: 0.01783
# Epoch 10/50   -   loss: 0.01792   -   val_loss: 0.01763
# Epoch 11/50   -   loss: 0.01760   -   val_loss: 0.01778
# Epoch 12/50   -   loss: 0.01737   -   val_loss: 0.01753
# Epoch 13/50   -   loss: 0.01695   -   val_loss: 0.01744
# Epoch 14/50   -   loss: 0.01662   -   val_loss: 0.01750
# Epoch 15/50   -   loss: 0.01655   -   val_loss: 0.01741
# Epoch 16/50   -   loss: 0.01621   -   val_loss: 0.01736
# Epoch 17/50   -   loss: 0.01590   -   val_loss: 0.01734
# Epoch 18/50   -   loss: 0.01576   -   val_loss: 0.01730
# Epoch 19/50   -   loss: 0.01550   -   val_loss: 0.01735
# Epoch 20/50   -   loss: 0.01542   -   val_loss: 0.01734
# Epoch 21/50   -   loss: 0.01521   -   val_loss: 0.01736
# Epoch 22/50   -   loss: 0.01509   -   val_loss: 0.01735
# Epoch    22: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 23/50   -   loss: 0.01445   -   val_loss: 0.01722
# Epoch 24/50   -   loss: 0.01415   -   val_loss: 0.01723
# Epoch 25/50   -   loss: 0.01403   -   val_loss: 0.01724
# Epoch 26/50   -   loss: 0.01383   -   val_loss: 0.01724
# Epoch 27/50   -   loss: 0.01371   -   val_loss: 0.01728
# Epoch 28/50   -   loss: 0.01355   -   val_loss: 0.01727
# Epoch 29/50   -   loss: 0.01348   -   val_loss: 0.01729
# Epoch 30/50   -   loss: 0.01337   -   val_loss: 0.01729
# Epoch 31/50   -   loss: 0.01325   -   val_loss: 0.01731
# Epoch 32/50   -   loss: 0.01312   -   val_loss: 0.01733
# Epoch 33/50   -   loss: 0.01301   -   val_loss: 0.01735
# Epoch 34/50   -   loss: 0.01293   -   val_loss: 0.01735
# Epoch 35/50   -   loss: 0.01283   -   val_loss: 0.01738
# Epoch 36/50   -   loss: 0.01269   -   val_loss: 0.01742
# Epoch 37/50   -   loss: 0.01258   -   val_loss: 0.01745
# Epoch 38/50   -   loss: 0.01252   -   val_loss: 0.01746
# Epoch 39/50   -   loss: 0.01237   -   val_loss: 0.01753
# Epoch 40/50   -   loss: 0.01224   -   val_loss: 0.01751
# Epoch 41/50   -   loss: 0.01219   -   val_loss: 0.01753
# Epoch 42/50   -   loss: 0.01203   -   val_loss: 0.01756
# Epoch 43/50   -   loss: 0.01198   -   val_loss: 0.01760
# Epoch 44/50   -   loss: 0.01184   -   val_loss: 0.01761
# Epoch 45/50   -   loss: 0.01178   -   val_loss: 0.01760
# Epoch 46/50   -   loss: 0.01169   -   val_loss: 0.01763
# Epoch 47/50   -   loss: 0.01150   -   val_loss: 0.01766
# Epoch 48/50   -   loss: 0.01139   -   val_loss: 0.01768
# Epoch 49/50   -   loss: 0.01130   -   val_loss: 0.01775
# Epoch 50/50   -   loss: 0.01117   -   val_loss: 0.01772
# Epoch 1/50   -   loss: 0.37917   -   val_loss: 0.06472
# Epoch 2/50   -   loss: 0.04239   -   val_loss: 0.02670
# Epoch 3/50   -   loss: 0.02557   -   val_loss: 0.02196
# Epoch 4/50   -   loss: 0.02239   -   val_loss: 0.02046
# Epoch 5/50   -   loss: 0.02065   -   val_loss: 0.01981
# Epoch 6/50   -   loss: 0.01995   -   val_loss: 0.01930
# Epoch 7/50   -   loss: 0.01915   -   val_loss: 0.01884
# Epoch 8/50   -   loss: 0.01869   -   val_loss: 0.01849
# Epoch 9/50   -   loss: 0.01814   -   val_loss: 0.01815
# Epoch 10/50   -   loss: 0.01794   -   val_loss: 0.01827
# Epoch 11/50   -   loss: 0.01753   -   val_loss: 0.01802
# Epoch 12/50   -   loss: 0.01721   -   val_loss: 0.01789
# Epoch 13/50   -   loss: 0.01683   -   val_loss: 0.01783
# Epoch 14/50   -   loss: 0.01674   -   val_loss: 0.01868
# Epoch 15/50   -   loss: 0.01659   -   val_loss: 0.01779
# Epoch 16/50   -   loss: 0.01616   -   val_loss: 0.01770
# Epoch 17/50   -   loss: 0.01590   -   val_loss: 0.01789
# Epoch 18/50   -   loss: 0.01577   -   val_loss: 0.01773
# Epoch 19/50   -   loss: 0.01549   -   val_loss: 0.01774
# Epoch 20/50   -   loss: 0.01545   -   val_loss: 0.01773
# Epoch    20: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 21/50   -   loss: 0.01472   -   val_loss: 0.01763
# Epoch 22/50   -   loss: 0.01450   -   val_loss: 0.01760
# Epoch 23/50   -   loss: 0.01431   -   val_loss: 0.01759
# Epoch 24/50   -   loss: 0.01425   -   val_loss: 0.01761
# Epoch 25/50   -   loss: 0.01407   -   val_loss: 0.01761
# Epoch 26/50   -   loss: 0.01399   -   val_loss: 0.01762
# Epoch 27/50   -   loss: 0.01388   -   val_loss: 0.01762
# Epoch 28/50   -   loss: 0.01377   -   val_loss: 0.01763
# Epoch 29/50   -   loss: 0.01364   -   val_loss: 0.01763
# Epoch 30/50   -   loss: 0.01354   -   val_loss: 0.01766
# Epoch 31/50   -   loss: 0.01343   -   val_loss: 0.01766
# Epoch 32/50   -   loss: 0.01330   -   val_loss: 0.01766
# Epoch 33/50   -   loss: 0.01326   -   val_loss: 0.01767
# Epoch 34/50   -   loss: 0.01316   -   val_loss: 0.01769
# Epoch 35/50   -   loss: 0.01306   -   val_loss: 0.01770
# Epoch 36/50   -   loss: 0.01295   -   val_loss: 0.01772
# Epoch 37/50   -   loss: 0.01285   -   val_loss: 0.01775
# Epoch 38/50   -   loss: 0.01273   -   val_loss: 0.01778
# Epoch 39/50   -   loss: 0.01260   -   val_loss: 0.01780
# Epoch 40/50   -   loss: 0.01255   -   val_loss: 0.01780
# Epoch 41/50   -   loss: 0.01245   -   val_loss: 0.01781
# Epoch 42/50   -   loss: 0.01233   -   val_loss: 0.01782
# Epoch 43/50   -   loss: 0.01218   -   val_loss: 0.01784
# Epoch 44/50   -   loss: 0.01209   -   val_loss: 0.01791
# Epoch 45/50   -   loss: 0.01194   -   val_loss: 0.01792
# Epoch 46/50   -   loss: 0.01186   -   val_loss: 0.01797
# Epoch 47/50   -   loss: 0.01175   -   val_loss: 0.01795
# Epoch 48/50   -   loss: 0.01167   -   val_loss: 0.01795
# Epoch 49/50   -   loss: 0.01155   -   val_loss: 0.01798
# Epoch 50/50   -   loss: 0.01138   -   val_loss: 0.01798
# Epoch 1/50   -   loss: 0.38264   -   val_loss: 0.06415
# Epoch 2/50   -   loss: 0.04244   -   val_loss: 0.02672
# Epoch 3/50   -   loss: 0.02574   -   val_loss: 0.02209
# Epoch 4/50   -   loss: 0.02246   -   val_loss: 0.01997
# Epoch 5/50   -   loss: 0.02074   -   val_loss: 0.01895
# Epoch 6/50   -   loss: 0.01977   -   val_loss: 0.01847
# Epoch 7/50   -   loss: 0.01912   -   val_loss: 0.01802
# Epoch 8/50   -   loss: 0.01882   -   val_loss: 0.01773
# Epoch 9/50   -   loss: 0.01817   -   val_loss: 0.01740
# Epoch 10/50   -   loss: 0.01800   -   val_loss: 0.01735
# Epoch 11/50   -   loss: 0.01767   -   val_loss: 0.01719
# Epoch 12/50   -   loss: 0.01730   -   val_loss: 0.01711
# Epoch 13/50   -   loss: 0.01706   -   val_loss: 0.01701
# Epoch 14/50   -   loss: 0.01674   -   val_loss: 0.01686
# Epoch 15/50   -   loss: 0.01649   -   val_loss: 0.01712
# Epoch 16/50   -   loss: 0.01629   -   val_loss: 0.01683
# Epoch 17/50   -   loss: 0.01600   -   val_loss: 0.01679
# Epoch 18/50   -   loss: 0.01581   -   val_loss: 0.01683
# Epoch 19/50   -   loss: 0.01572   -   val_loss: 0.01678
# Epoch 20/50   -   loss: 0.01552   -   val_loss: 0.01679
# Epoch 21/50   -   loss: 0.01533   -   val_loss: 0.01684
# Epoch 22/50   -   loss: 0.01528   -   val_loss: 0.01684
# Epoch 23/50   -   loss: 0.01506   -   val_loss: 0.01681
# Epoch    23: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 24/50   -   loss: 0.01431   -   val_loss: 0.01667
# Epoch 25/50   -   loss: 0.01407   -   val_loss: 0.01667
# Epoch 26/50   -   loss: 0.01388   -   val_loss: 0.01666
# Epoch 27/50   -   loss: 0.01375   -   val_loss: 0.01667
# Epoch 28/50   -   loss: 0.01361   -   val_loss: 0.01666
# Epoch 29/50   -   loss: 0.01351   -   val_loss: 0.01666
# Epoch 30/50   -   loss: 0.01338   -   val_loss: 0.01665
# Epoch 31/50   -   loss: 0.01328   -   val_loss: 0.01669
# Epoch 32/50   -   loss: 0.01312   -   val_loss: 0.01670
# Epoch 33/50   -   loss: 0.01310   -   val_loss: 0.01673
# Epoch 34/50   -   loss: 0.01292   -   val_loss: 0.01673
# Epoch 35/50   -   loss: 0.01285   -   val_loss: 0.01673
# Epoch 36/50   -   loss: 0.01267   -   val_loss: 0.01673
# Epoch 37/50   -   loss: 0.01259   -   val_loss: 0.01679
# Epoch 38/50   -   loss: 0.01254   -   val_loss: 0.01678
# Epoch 39/50   -   loss: 0.01243   -   val_loss: 0.01677
# Epoch 40/50   -   loss: 0.01226   -   val_loss: 0.01681
# Epoch 41/50   -   loss: 0.01215   -   val_loss: 0.01681
# Epoch 42/50   -   loss: 0.01210   -   val_loss: 0.01686
# Epoch 43/50   -   loss: 0.01197   -   val_loss: 0.01687
# Epoch 44/50   -   loss: 0.01186   -   val_loss: 0.01690
# Epoch 45/50   -   loss: 0.01175   -   val_loss: 0.01688
# Epoch 46/50   -   loss: 0.01161   -   val_loss: 0.01688
# Epoch 47/50   -   loss: 0.01160   -   val_loss: 0.01693
# Epoch 48/50   -   loss: 0.01148   -   val_loss: 0.01693
# Epoch 49/50   -   loss: 0.01132   -   val_loss: 0.01695
# Epoch 50/50   -   loss: 0.01117   -   val_loss: 0.01699
# Epoch 1/50   -   loss: 0.37466   -   val_loss: 0.06262
# Epoch 2/50   -   loss: 0.04264   -   val_loss: 0.02741
# Epoch 3/50   -   loss: 0.02518   -   val_loss: 0.02332
# Epoch 4/50   -   loss: 0.02194   -   val_loss: 0.02149
# Epoch 5/50   -   loss: 0.02054   -   val_loss: 0.02075
# Epoch 6/50   -   loss: 0.01974   -   val_loss: 0.02013
# Epoch 7/50   -   loss: 0.01916   -   val_loss: 0.01967
# Epoch 8/50   -   loss: 0.01874   -   val_loss: 0.01938
# Epoch 9/50   -   loss: 0.01826   -   val_loss: 0.01913
# Epoch 10/50   -   loss: 0.01792   -   val_loss: 0.01910
# Epoch 11/50   -   loss: 0.01765   -   val_loss: 0.01877
# Epoch 12/50   -   loss: 0.01734   -   val_loss: 0.01863
# Epoch 13/50   -   loss: 0.01715   -   val_loss: 0.01831
# Epoch 14/50   -   loss: 0.01692   -   val_loss: 0.01843
# Epoch 15/50   -   loss: 0.01656   -   val_loss: 0.01814
# Epoch 16/50   -   loss: 0.01632   -   val_loss: 0.01814
# Epoch 17/50   -   loss: 0.01634   -   val_loss: 0.01803
# Epoch 18/50   -   loss: 0.01619   -   val_loss: 0.01809
# Epoch 19/50   -   loss: 0.01593   -   val_loss: 0.01796
# Epoch 20/50   -   loss: 0.01564   -   val_loss: 0.01804
# Epoch 21/50   -   loss: 0.01558   -   val_loss: 0.01791
# Epoch 22/50   -   loss: 0.01553   -   val_loss: 0.01796
# Epoch 23/50   -   loss: 0.01533   -   val_loss: 0.01793
# Epoch 24/50   -   loss: 0.01517   -   val_loss: 0.01804
# Epoch 25/50   -   loss: 0.01526   -   val_loss: 0.01806
# Epoch    25: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 26/50   -   loss: 0.01451   -   val_loss: 0.01781
# Epoch 27/50   -   loss: 0.01443   -   val_loss: 0.01775
# Epoch 28/50   -   loss: 0.01410   -   val_loss: 0.01777
# Epoch 29/50   -   loss: 0.01411   -   val_loss: 0.01771
# Epoch 30/50   -   loss: 0.01400   -   val_loss: 0.01774
# Epoch 31/50   -   loss: 0.01382   -   val_loss: 0.01775
# Epoch 32/50   -   loss: 0.01374   -   val_loss: 0.01785
# Epoch 33/50   -   loss: 0.01371   -   val_loss: 0.01781
# Epoch 34/50   -   loss: 0.01361   -   val_loss: 0.01779
# Epoch 35/50   -   loss: 0.01349   -   val_loss: 0.01780
# Epoch 36/50   -   loss: 0.01340   -   val_loss: 0.01779
# Epoch 37/50   -   loss: 0.01338   -   val_loss: 0.01786
# Epoch 38/50   -   loss: 0.01324   -   val_loss: 0.01781
# Epoch 39/50   -   loss: 0.01318   -   val_loss: 0.01793
# Epoch 40/50   -   loss: 0.01310   -   val_loss: 0.01786
# Epoch 41/50   -   loss: 0.01299   -   val_loss: 0.01786
# Epoch 42/50   -   loss: 0.01295   -   val_loss: 0.01791
# Epoch 43/50   -   loss: 0.01286   -   val_loss: 0.01789
# Epoch 44/50   -   loss: 0.01286   -   val_loss: 0.01795
# Epoch 45/50   -   loss: 0.01269   -   val_loss: 0.01791
# Epoch 46/50   -   loss: 0.01274   -   val_loss: 0.01793
# Epoch 47/50   -   loss: 0.01254   -   val_loss: 0.01800
# Epoch 48/50   -   loss: 0.01254   -   val_loss: 0.01796
# Epoch 49/50   -   loss: 0.01240   -   val_loss: 0.01802
# Epoch 50/50   -   loss: 0.01235   -   val_loss: 0.01802
# Epoch 1/50   -   loss: 0.37232   -   val_loss: 0.06441
# Epoch 2/50   -   loss: 0.04157   -   val_loss: 0.02640
# Epoch 3/50   -   loss: 0.02565   -   val_loss: 0.02230
# Epoch 4/50   -   loss: 0.02253   -   val_loss: 0.02015
# Epoch 5/50   -   loss: 0.02065   -   val_loss: 0.01928
# Epoch 6/50   -   loss: 0.01977   -   val_loss: 0.01903
# Epoch 7/50   -   loss: 0.01915   -   val_loss: 0.01846
# Epoch 8/50   -   loss: 0.01862   -   val_loss: 0.01812
# Epoch 9/50   -   loss: 0.01816   -   val_loss: 0.01784
# Epoch 10/50   -   loss: 0.01776   -   val_loss: 0.01760
# Epoch 11/50   -   loss: 0.01751   -   val_loss: 0.01740
# Epoch 12/50   -   loss: 0.01713   -   val_loss: 0.01751
# Epoch 13/50   -   loss: 0.01680   -   val_loss: 0.01727
# Epoch 14/50   -   loss: 0.01659   -   val_loss: 0.01714
# Epoch 15/50   -   loss: 0.01630   -   val_loss: 0.01743
# Epoch 16/50   -   loss: 0.01609   -   val_loss: 0.01720
# Epoch 17/50   -   loss: 0.01586   -   val_loss: 0.01711
# Epoch 18/50   -   loss: 0.01565   -   val_loss: 0.01700
# Epoch 19/50   -   loss: 0.01553   -   val_loss: 0.01718
# Epoch 20/50   -   loss: 0.01531   -   val_loss: 0.01702
# Epoch 21/50   -   loss: 0.01518   -   val_loss: 0.01711
# Epoch 22/50   -   loss: 0.01505   -   val_loss: 0.01709
# Epoch    22: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 23/50   -   loss: 0.01425   -   val_loss: 0.01692
# Epoch 24/50   -   loss: 0.01402   -   val_loss: 0.01689
# Epoch 25/50   -   loss: 0.01382   -   val_loss: 0.01693
# Epoch 26/50   -   loss: 0.01368   -   val_loss: 0.01693
# Epoch 27/50   -   loss: 0.01356   -   val_loss: 0.01690
# Epoch 28/50   -   loss: 0.01340   -   val_loss: 0.01694
# Epoch 29/50   -   loss: 0.01332   -   val_loss: 0.01694
# Epoch 30/50   -   loss: 0.01324   -   val_loss: 0.01696
# Epoch 31/50   -   loss: 0.01310   -   val_loss: 0.01696
# Epoch 32/50   -   loss: 0.01298   -   val_loss: 0.01699
# Epoch 33/50   -   loss: 0.01289   -   val_loss: 0.01702
# Epoch 34/50   -   loss: 0.01277   -   val_loss: 0.01701
# Epoch 35/50   -   loss: 0.01265   -   val_loss: 0.01702
# Epoch 36/50   -   loss: 0.01256   -   val_loss: 0.01704
# Epoch 37/50   -   loss: 0.01241   -   val_loss: 0.01710
# Epoch 38/50   -   loss: 0.01234   -   val_loss: 0.01709
# Epoch 39/50   -   loss: 0.01217   -   val_loss: 0.01705
# Epoch 40/50   -   loss: 0.01205   -   val_loss: 0.01712
# Epoch 41/50   -   loss: 0.01199   -   val_loss: 0.01711
# Epoch 42/50   -   loss: 0.01189   -   val_loss: 0.01714
# Epoch 43/50   -   loss: 0.01185   -   val_loss: 0.01711
# Epoch 44/50   -   loss: 0.01165   -   val_loss: 0.01718
# Epoch 45/50   -   loss: 0.01157   -   val_loss: 0.01716
# Epoch 46/50   -   loss: 0.01145   -   val_loss: 0.01717
# Epoch 47/50   -   loss: 0.01132   -   val_loss: 0.01723
# Epoch 48/50   -   loss: 0.01118   -   val_loss: 0.01725
# Epoch 49/50   -   loss: 0.01115   -   val_loss: 0.01728
# Epoch 50/50   -   loss: 0.01107   -   val_loss: 0.01724
# Epoch 1/50   -   loss: 0.37772   -   val_loss: 0.06315
# Epoch 2/50   -   loss: 0.04332   -   val_loss: 0.02793
# Epoch 3/50   -   loss: 0.02577   -   val_loss: 0.02254
# Epoch 4/50   -   loss: 0.02246   -   val_loss: 0.02110
# Epoch 5/50   -   loss: 0.02087   -   val_loss: 0.01925
# Epoch 6/50   -   loss: 0.02003   -   val_loss: 0.01886
# Epoch 7/50   -   loss: 0.01926   -   val_loss: 0.01831
# Epoch 8/50   -   loss: 0.01873   -   val_loss: 0.01811
# Epoch 9/50   -   loss: 0.01832   -   val_loss: 0.01773
# Epoch 10/50   -   loss: 0.01793   -   val_loss: 0.01750
# Epoch 11/50   -   loss: 0.01759   -   val_loss: 0.01731
# Epoch 12/50   -   loss: 0.01723   -   val_loss: 0.01711
# Epoch 13/50   -   loss: 0.01707   -   val_loss: 0.01728
# Epoch 14/50   -   loss: 0.01689   -   val_loss: 0.01727
# Epoch 15/50   -   loss: 0.01649   -   val_loss: 0.01688
# Epoch 16/50   -   loss: 0.01625   -   val_loss: 0.01684
# Epoch 17/50   -   loss: 0.01604   -   val_loss: 0.01698
# Epoch 18/50   -   loss: 0.01586   -   val_loss: 0.01683
# Epoch 19/50   -   loss: 0.01570   -   val_loss: 0.01675
# Epoch 20/50   -   loss: 0.01552   -   val_loss: 0.01691
# Epoch 21/50   -   loss: 0.01540   -   val_loss: 0.01675
# Epoch 22/50   -   loss: 0.01519   -   val_loss: 0.01686
# Epoch 23/50   -   loss: 0.01515   -   val_loss: 0.01692
# Epoch    23: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 24/50   -   loss: 0.01440   -   val_loss: 0.01668
# Epoch 25/50   -   loss: 0.01410   -   val_loss: 0.01668
# Epoch 26/50   -   loss: 0.01388   -   val_loss: 0.01669
# Epoch 27/50   -   loss: 0.01378   -   val_loss: 0.01667
# Epoch 28/50   -   loss: 0.01362   -   val_loss: 0.01672
# Epoch 29/50   -   loss: 0.01352   -   val_loss: 0.01669
# Epoch 30/50   -   loss: 0.01337   -   val_loss: 0.01673
# Epoch 31/50   -   loss: 0.01324   -   val_loss: 0.01674
# Epoch 32/50   -   loss: 0.01314   -   val_loss: 0.01672
# Epoch 33/50   -   loss: 0.01306   -   val_loss: 0.01673
# Epoch 34/50   -   loss: 0.01292   -   val_loss: 0.01676
# Epoch 35/50   -   loss: 0.01279   -   val_loss: 0.01679
# Epoch 36/50   -   loss: 0.01275   -   val_loss: 0.01684
# Epoch 37/50   -   loss: 0.01260   -   val_loss: 0.01679
# Epoch 38/50   -   loss: 0.01249   -   val_loss: 0.01683
# Epoch 39/50   -   loss: 0.01241   -   val_loss: 0.01682
# Epoch 40/50   -   loss: 0.01234   -   val_loss: 0.01689
# Epoch 41/50   -   loss: 0.01224   -   val_loss: 0.01687
# Epoch 42/50   -   loss: 0.01206   -   val_loss: 0.01695
# Epoch 43/50   -   loss: 0.01200   -   val_loss: 0.01695
# Epoch 44/50   -   loss: 0.01194   -   val_loss: 0.01694
# Epoch 45/50   -   loss: 0.01178   -   val_loss: 0.01699
# Epoch 46/50   -   loss: 0.01169   -   val_loss: 0.01697
# Epoch 47/50   -   loss: 0.01160   -   val_loss: 0.01697
# Epoch 48/50   -   loss: 0.01145   -   val_loss: 0.01696
# Epoch 49/50   -   loss: 0.01141   -   val_loss: 0.01700
# Epoch 50/50   -   loss: 0.01132   -   val_loss: 0.01702
# Train seed 2
# Epoch 1/50   -   loss: 0.37665   -   val_loss: 0.06325
# Epoch 2/50   -   loss: 0.04266   -   val_loss: 0.02776
# Epoch 3/50   -   loss: 0.02592   -   val_loss: 0.02194
# Epoch 4/50   -   loss: 0.02221   -   val_loss: 0.02064
# Epoch 5/50   -   loss: 0.02056   -   val_loss: 0.01968
# Epoch 6/50   -   loss: 0.01976   -   val_loss: 0.01925
# Epoch 7/50   -   loss: 0.01907   -   val_loss: 0.01881
# Epoch 8/50   -   loss: 0.01854   -   val_loss: 0.01859
# Epoch 9/50   -   loss: 0.01859   -   val_loss: 0.01839
# Epoch 10/50   -   loss: 0.01801   -   val_loss: 0.01817
# Epoch 11/50   -   loss: 0.01759   -   val_loss: 0.01796
# Epoch 12/50   -   loss: 0.01718   -   val_loss: 0.01793
# Epoch 13/50   -   loss: 0.01691   -   val_loss: 0.01785
# Epoch 14/50   -   loss: 0.01669   -   val_loss: 0.01780
# Epoch 15/50   -   loss: 0.01652   -   val_loss: 0.01767
# Epoch 16/50   -   loss: 0.01631   -   val_loss: 0.01765
# Epoch 17/50   -   loss: 0.01594   -   val_loss: 0.01764
# Epoch 18/50   -   loss: 0.01575   -   val_loss: 0.01766
# Epoch 19/50   -   loss: 0.01569   -   val_loss: 0.01773
# Epoch 20/50   -   loss: 0.01541   -   val_loss: 0.01768
# Epoch 21/50   -   loss: 0.01522   -   val_loss: 0.01776
# Epoch    21: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 22/50   -   loss: 0.01453   -   val_loss: 0.01756
# Epoch 23/50   -   loss: 0.01428   -   val_loss: 0.01751
# Epoch 24/50   -   loss: 0.01409   -   val_loss: 0.01747
# Epoch 25/50   -   loss: 0.01394   -   val_loss: 0.01751
# Epoch 26/50   -   loss: 0.01383   -   val_loss: 0.01748
# Epoch 27/50   -   loss: 0.01380   -   val_loss: 0.01749
# Epoch 28/50   -   loss: 0.01364   -   val_loss: 0.01752
# Epoch 29/50   -   loss: 0.01353   -   val_loss: 0.01755
# Epoch 30/50   -   loss: 0.01339   -   val_loss: 0.01754
# Epoch 31/50   -   loss: 0.01326   -   val_loss: 0.01758
# Epoch 32/50   -   loss: 0.01321   -   val_loss: 0.01758
# Epoch 33/50   -   loss: 0.01309   -   val_loss: 0.01766
# Epoch 34/50   -   loss: 0.01296   -   val_loss: 0.01764
# Epoch 35/50   -   loss: 0.01288   -   val_loss: 0.01769
# Epoch 36/50   -   loss: 0.01274   -   val_loss: 0.01771
# Epoch 37/50   -   loss: 0.01267   -   val_loss: 0.01773
# Epoch 38/50   -   loss: 0.01255   -   val_loss: 0.01774
# Epoch 39/50   -   loss: 0.01244   -   val_loss: 0.01776
# Epoch 40/50   -   loss: 0.01231   -   val_loss: 0.01779
# Epoch 41/50   -   loss: 0.01222   -   val_loss: 0.01787
# Epoch 42/50   -   loss: 0.01219   -   val_loss: 0.01786
# Epoch 43/50   -   loss: 0.01200   -   val_loss: 0.01789
# Epoch 44/50   -   loss: 0.01191   -   val_loss: 0.01791
# Epoch 45/50   -   loss: 0.01177   -   val_loss: 0.01796
# Epoch 46/50   -   loss: 0.01171   -   val_loss: 0.01798
# Epoch 47/50   -   loss: 0.01156   -   val_loss: 0.01798
# Epoch 48/50   -   loss: 0.01148   -   val_loss: 0.01805
# Epoch 49/50   -   loss: 0.01133   -   val_loss: 0.01805
# Epoch 50/50   -   loss: 0.01120   -   val_loss: 0.01812
# Epoch 1/50   -   loss: 0.37955   -   val_loss: 0.06294
# Epoch 2/50   -   loss: 0.04258   -   val_loss: 0.02739
# Epoch 3/50   -   loss: 0.02597   -   val_loss: 0.02259
# Epoch 4/50   -   loss: 0.02211   -   val_loss: 0.02045
# Epoch 5/50   -   loss: 0.02066   -   val_loss: 0.01994
# Epoch 6/50   -   loss: 0.01988   -   val_loss: 0.01981
# Epoch 7/50   -   loss: 0.01911   -   val_loss: 0.01872
# Epoch 8/50   -   loss: 0.01863   -   val_loss: 0.01851
# Epoch 9/50   -   loss: 0.01818   -   val_loss: 0.01818
# Epoch 10/50   -   loss: 0.01779   -   val_loss: 0.01807
# Epoch 11/50   -   loss: 0.01748   -   val_loss: 0.01778
# Epoch 12/50   -   loss: 0.01709   -   val_loss: 0.01777
# Epoch 13/50   -   loss: 0.01667   -   val_loss: 0.01760
# Epoch 14/50   -   loss: 0.01663   -   val_loss: 0.01777
# Epoch 15/50   -   loss: 0.01626   -   val_loss: 0.01747
# Epoch 16/50   -   loss: 0.01603   -   val_loss: 0.01743
# Epoch 17/50   -   loss: 0.01587   -   val_loss: 0.01742
# Epoch 18/50   -   loss: 0.01567   -   val_loss: 0.01745
# Epoch 19/50   -   loss: 0.01554   -   val_loss: 0.01744
# Epoch 20/50   -   loss: 0.01524   -   val_loss: 0.01742
# Epoch 21/50   -   loss: 0.01504   -   val_loss: 0.01746
# Epoch 22/50   -   loss: 0.01494   -   val_loss: 0.01737
# Epoch 23/50   -   loss: 0.01482   -   val_loss: 0.01736
# Epoch 24/50   -   loss: 0.01465   -   val_loss: 0.01737
# Epoch 25/50   -   loss: 0.01455   -   val_loss: 0.01744
# Epoch 26/50   -   loss: 0.01443   -   val_loss: 0.01738
# Epoch 27/50   -   loss: 0.01434   -   val_loss: 0.01751
# Epoch    27: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 28/50   -   loss: 0.01354   -   val_loss: 0.01731
# Epoch 29/50   -   loss: 0.01318   -   val_loss: 0.01732
# Epoch 30/50   -   loss: 0.01297   -   val_loss: 0.01729
# Epoch 31/50   -   loss: 0.01282   -   val_loss: 0.01730
# Epoch 32/50   -   loss: 0.01269   -   val_loss: 0.01733
# Epoch 33/50   -   loss: 0.01251   -   val_loss: 0.01733
# Epoch 34/50   -   loss: 0.01239   -   val_loss: 0.01739
# Epoch 35/50   -   loss: 0.01226   -   val_loss: 0.01737
# Epoch 36/50   -   loss: 0.01216   -   val_loss: 0.01739
# Epoch 37/50   -   loss: 0.01204   -   val_loss: 0.01742
# Epoch 38/50   -   loss: 0.01192   -   val_loss: 0.01747
# Epoch 39/50   -   loss: 0.01184   -   val_loss: 0.01745
# Epoch 40/50   -   loss: 0.01170   -   val_loss: 0.01745
# Epoch 41/50   -   loss: 0.01163   -   val_loss: 0.01748
# Epoch 42/50   -   loss: 0.01147   -   val_loss: 0.01751
# Epoch 43/50   -   loss: 0.01138   -   val_loss: 0.01756
# Epoch 44/50   -   loss: 0.01131   -   val_loss: 0.01751
# Epoch 45/50   -   loss: 0.01119   -   val_loss: 0.01755
# Epoch 46/50   -   loss: 0.01104   -   val_loss: 0.01761
# Epoch 47/50   -   loss: 0.01099   -   val_loss: 0.01759
# Epoch 48/50   -   loss: 0.01087   -   val_loss: 0.01759
# Epoch 49/50   -   loss: 0.01080   -   val_loss: 0.01769
# Epoch 50/50   -   loss: 0.01072   -   val_loss: 0.01764
# Epoch 1/50   -   loss: 0.37385   -   val_loss: 0.07213
# Epoch 2/50   -   loss: 0.04212   -   val_loss: 0.02640
# Epoch 3/50   -   loss: 0.02563   -   val_loss: 0.02170
# Epoch 4/50   -   loss: 0.02263   -   val_loss: 0.02022
# Epoch 5/50   -   loss: 0.02056   -   val_loss: 0.01952
# Epoch 6/50   -   loss: 0.01992   -   val_loss: 0.01881
# Epoch 7/50   -   loss: 0.01939   -   val_loss: 0.01849
# Epoch 8/50   -   loss: 0.01885   -   val_loss: 0.01807
# Epoch 9/50   -   loss: 0.01826   -   val_loss: 0.01778
# Epoch 10/50   -   loss: 0.01799   -   val_loss: 0.01755
# Epoch 11/50   -   loss: 0.01766   -   val_loss: 0.01732
# Epoch 12/50   -   loss: 0.01738   -   val_loss: 0.01730
# Epoch 13/50   -   loss: 0.01714   -   val_loss: 0.01708
# Epoch 14/50   -   loss: 0.01684   -   val_loss: 0.01706
# Epoch 15/50   -   loss: 0.01660   -   val_loss: 0.01708
# Epoch 16/50   -   loss: 0.01643   -   val_loss: 0.01705
# Epoch 17/50   -   loss: 0.01617   -   val_loss: 0.01696
# Epoch 18/50   -   loss: 0.01615   -   val_loss: 0.01707
# Epoch 19/50   -   loss: 0.01591   -   val_loss: 0.01693
# Epoch 20/50   -   loss: 0.01562   -   val_loss: 0.01691
# Epoch 21/50   -   loss: 0.01568   -   val_loss: 0.01686
# Epoch 22/50   -   loss: 0.01545   -   val_loss: 0.01693
# Epoch 23/50   -   loss: 0.01521   -   val_loss: 0.01697
# Epoch 24/50   -   loss: 0.01521   -   val_loss: 0.01693
# Epoch 25/50   -   loss: 0.01503   -   val_loss: 0.01697
# Epoch    25: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 26/50   -   loss: 0.01429   -   val_loss: 0.01690
# Epoch 27/50   -   loss: 0.01409   -   val_loss: 0.01687
# Epoch 28/50   -   loss: 0.01391   -   val_loss: 0.01682
# Epoch 29/50   -   loss: 0.01370   -   val_loss: 0.01682
# Epoch 30/50   -   loss: 0.01363   -   val_loss: 0.01683
# Epoch 31/50   -   loss: 0.01346   -   val_loss: 0.01687
# Epoch 32/50   -   loss: 0.01343   -   val_loss: 0.01684
# Epoch 33/50   -   loss: 0.01331   -   val_loss: 0.01690
# Epoch 34/50   -   loss: 0.01324   -   val_loss: 0.01684
# Epoch 35/50   -   loss: 0.01314   -   val_loss: 0.01689
# Epoch 36/50   -   loss: 0.01300   -   val_loss: 0.01690
# Epoch 37/50   -   loss: 0.01290   -   val_loss: 0.01691
# Epoch 38/50   -   loss: 0.01277   -   val_loss: 0.01696
# Epoch 39/50   -   loss: 0.01267   -   val_loss: 0.01693
# Epoch 40/50   -   loss: 0.01254   -   val_loss: 0.01696
# Epoch 41/50   -   loss: 0.01248   -   val_loss: 0.01700
# Epoch 42/50   -   loss: 0.01241   -   val_loss: 0.01704
# Epoch 43/50   -   loss: 0.01227   -   val_loss: 0.01700
# Epoch 44/50   -   loss: 0.01218   -   val_loss: 0.01702
# Epoch 45/50   -   loss: 0.01211   -   val_loss: 0.01706
# Epoch 46/50   -   loss: 0.01198   -   val_loss: 0.01708
# Epoch 47/50   -   loss: 0.01193   -   val_loss: 0.01710
# Epoch 48/50   -   loss: 0.01182   -   val_loss: 0.01709
# Epoch 49/50   -   loss: 0.01167   -   val_loss: 0.01713
# Epoch 50/50   -   loss: 0.01166   -   val_loss: 0.01716
# Epoch 1/50   -   loss: 0.37772   -   val_loss: 0.06762
# Epoch 2/50   -   loss: 0.04326   -   val_loss: 0.03168
# Epoch 3/50   -   loss: 0.02591   -   val_loss: 0.02153
# Epoch 4/50   -   loss: 0.02209   -   val_loss: 0.01986
# Epoch 5/50   -   loss: 0.02074   -   val_loss: 0.01918
# Epoch 6/50   -   loss: 0.01990   -   val_loss: 0.01860
# Epoch 7/50   -   loss: 0.01902   -   val_loss: 0.01825
# Epoch 8/50   -   loss: 0.01853   -   val_loss: 0.01787
# Epoch 9/50   -   loss: 0.01822   -   val_loss: 0.01770
# Epoch 10/50   -   loss: 0.01785   -   val_loss: 0.01761
# Epoch 11/50   -   loss: 0.01755   -   val_loss: 0.01740
# Epoch 12/50   -   loss: 0.01718   -   val_loss: 0.01744
# Epoch 13/50   -   loss: 0.01695   -   val_loss: 0.01734
# Epoch 14/50   -   loss: 0.01682   -   val_loss: 0.01720
# Epoch 15/50   -   loss: 0.01647   -   val_loss: 0.01720
# Epoch 16/50   -   loss: 0.01637   -   val_loss: 0.01719
# Epoch 17/50   -   loss: 0.01605   -   val_loss: 0.01709
# Epoch 18/50   -   loss: 0.01577   -   val_loss: 0.01714
# Epoch 19/50   -   loss: 0.01563   -   val_loss: 0.01705
# Epoch 20/50   -   loss: 0.01548   -   val_loss: 0.01706
# Epoch 21/50   -   loss: 0.01528   -   val_loss: 0.01704
# Epoch 22/50   -   loss: 0.01517   -   val_loss: 0.01705
# Epoch 23/50   -   loss: 0.01486   -   val_loss: 0.01707
# Epoch 24/50   -   loss: 0.01484   -   val_loss: 0.01721
# Epoch 25/50   -   loss: 0.01474   -   val_loss: 0.01719
# Epoch    25: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 26/50   -   loss: 0.01396   -   val_loss: 0.01701
# Epoch 27/50   -   loss: 0.01364   -   val_loss: 0.01700
# Epoch 28/50   -   loss: 0.01340   -   val_loss: 0.01702
# Epoch 29/50   -   loss: 0.01332   -   val_loss: 0.01703
# Epoch 30/50   -   loss: 0.01319   -   val_loss: 0.01704
# Epoch 31/50   -   loss: 0.01306   -   val_loss: 0.01707
# Epoch 32/50   -   loss: 0.01293   -   val_loss: 0.01707
# Epoch 33/50   -   loss: 0.01281   -   val_loss: 0.01710
# Epoch 34/50   -   loss: 0.01266   -   val_loss: 0.01711
# Epoch 35/50   -   loss: 0.01261   -   val_loss: 0.01713
# Epoch 36/50   -   loss: 0.01249   -   val_loss: 0.01718
# Epoch 37/50   -   loss: 0.01234   -   val_loss: 0.01720
# Epoch 38/50   -   loss: 0.01224   -   val_loss: 0.01720
# Epoch 39/50   -   loss: 0.01215   -   val_loss: 0.01721
# Epoch 40/50   -   loss: 0.01204   -   val_loss: 0.01724
# Epoch 41/50   -   loss: 0.01192   -   val_loss: 0.01727
# Epoch 42/50   -   loss: 0.01183   -   val_loss: 0.01725
# Epoch 43/50   -   loss: 0.01173   -   val_loss: 0.01726
# Epoch 44/50   -   loss: 0.01161   -   val_loss: 0.01736
# Epoch 45/50   -   loss: 0.01152   -   val_loss: 0.01733
# Epoch 46/50   -   loss: 0.01146   -   val_loss: 0.01736
# Epoch 47/50   -   loss: 0.01128   -   val_loss: 0.01736
# Epoch 48/50   -   loss: 0.01119   -   val_loss: 0.01740
# Epoch 49/50   -   loss: 0.01112   -   val_loss: 0.01744
# Epoch 50/50   -   loss: 0.01095   -   val_loss: 0.01744
# Epoch 1/50   -   loss: 0.37562   -   val_loss: 0.06464
# Epoch 2/50   -   loss: 0.04224   -   val_loss: 0.02650
# Epoch 3/50   -   loss: 0.02557   -   val_loss: 0.02138
# Epoch 4/50   -   loss: 0.02223   -   val_loss: 0.01997
# Epoch 5/50   -   loss: 0.02057   -   val_loss: 0.01912
# Epoch 6/50   -   loss: 0.01998   -   val_loss: 0.01854
# Epoch 7/50   -   loss: 0.01922   -   val_loss: 0.01806
# Epoch 8/50   -   loss: 0.01859   -   val_loss: 0.01786
# Epoch 9/50   -   loss: 0.01828   -   val_loss: 0.01788
# Epoch 10/50   -   loss: 0.01790   -   val_loss: 0.01735
# Epoch 11/50   -   loss: 0.01757   -   val_loss: 0.01734
# Epoch 12/50   -   loss: 0.01726   -   val_loss: 0.01729
# Epoch 13/50   -   loss: 0.01712   -   val_loss: 0.01704
# Epoch 14/50   -   loss: 0.01678   -   val_loss: 0.01702
# Epoch 15/50   -   loss: 0.01650   -   val_loss: 0.01709
# Epoch 16/50   -   loss: 0.01619   -   val_loss: 0.01696
# Epoch 17/50   -   loss: 0.01599   -   val_loss: 0.01711
# Epoch 18/50   -   loss: 0.01584   -   val_loss: 0.01699
# Epoch 19/50   -   loss: 0.01568   -   val_loss: 0.01700
# Epoch 20/50   -   loss: 0.01556   -   val_loss: 0.01704
# Epoch    20: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 21/50   -   loss: 0.01489   -   val_loss: 0.01682
# Epoch 22/50   -   loss: 0.01457   -   val_loss: 0.01680
# Epoch 23/50   -   loss: 0.01446   -   val_loss: 0.01677
# Epoch 24/50   -   loss: 0.01436   -   val_loss: 0.01674
# Epoch 25/50   -   loss: 0.01417   -   val_loss: 0.01678
# Epoch 26/50   -   loss: 0.01407   -   val_loss: 0.01675
# Epoch 27/50   -   loss: 0.01395   -   val_loss: 0.01678
# Epoch 28/50   -   loss: 0.01387   -   val_loss: 0.01678
# Epoch 29/50   -   loss: 0.01369   -   val_loss: 0.01678
# Epoch 30/50   -   loss: 0.01361   -   val_loss: 0.01683
# Epoch 31/50   -   loss: 0.01353   -   val_loss: 0.01683
# Epoch 32/50   -   loss: 0.01341   -   val_loss: 0.01685
# Epoch 33/50   -   loss: 0.01334   -   val_loss: 0.01687
# Epoch 34/50   -   loss: 0.01322   -   val_loss: 0.01689
# Epoch 35/50   -   loss: 0.01312   -   val_loss: 0.01692
# Epoch 36/50   -   loss: 0.01299   -   val_loss: 0.01693
# Epoch 37/50   -   loss: 0.01290   -   val_loss: 0.01697
# Epoch 38/50   -   loss: 0.01279   -   val_loss: 0.01704
# Epoch 39/50   -   loss: 0.01266   -   val_loss: 0.01704
# Epoch 40/50   -   loss: 0.01259   -   val_loss: 0.01704
# ...
# Epoch 22/50   -   loss: 0.01512   -   val_loss: 0.01751
# Epoch    22: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 23/50   -   loss: 0.01432   -   val_loss: 0.01737
# Epoch 24/50   -   loss: 0.01413   -   val_loss: 0.01734
# Epoch 25/50   -   loss: 0.01390   -   val_loss: 0.01735
# Epoch 26/50   -   loss: 0.01382   -   val_loss: 0.01741
# Epoch 27/50   -   loss: 0.01366   -   val_loss: 0.01741
# Epoch 28/50   -   loss: 0.01359   -   val_loss: 0.01743
# Epoch 29/50   -   loss: 0.01343   -   val_loss: 0.01746
# Epoch 30/50   -   loss: 0.01334   -   val_loss: 0.01747
# Epoch 31/50   -   loss: 0.01322   -   val_loss: 0.01745
# Epoch 32/50   -   loss: 0.01313   -   val_loss: 0.01749
# Epoch 33/50   -   loss: 0.01302   -   val_loss: 0.01753
# Epoch 34/50   -   loss: 0.01290   -   val_loss: 0.01755
# Epoch 35/50   -   loss: 0.01279   -   val_loss: 0.01752
# Epoch 36/50   -   loss: 0.01266   -   val_loss: 0.01758
# Epoch 37/50   -   loss: 0.01259   -   val_loss: 0.01760
# Epoch 38/50   -   loss: 0.01247   -   val_loss: 0.01762
# Epoch 39/50   -   loss: 0.01239   -   val_loss: 0.01767
# Epoch 40/50   -   loss: 0.01230   -   val_loss: 0.01767
# Epoch 41/50   -   loss: 0.01219   -   val_loss: 0.01768
# Epoch 42/50   -   loss: 0.01200   -   val_loss: 0.01770
# Epoch 43/50   -   loss: 0.01194   -   val_loss: 0.01774
# Epoch 44/50   -   loss: 0.01181   -   val_loss: 0.01773
# Epoch 45/50   -   loss: 0.01169   -   val_loss: 0.01778
# Epoch 46/50   -   loss: 0.01160   -   val_loss: 0.01778
# Epoch 47/50   -   loss: 0.01149   -   val_loss: 0.01781
# Epoch 48/50   -   loss: 0.01137   -   val_loss: 0.01782
# Epoch 49/50   -   loss: 0.01132   -   val_loss: 0.01789
# Epoch 50/50   -   loss: 0.01123   -   val_loss: 0.01786
# Epoch 1/50   -   loss: 0.37838   -   val_loss: 0.06660
# Epoch 2/50   -   loss: 0.04294   -   val_loss: 0.02806
# Epoch 3/50   -   loss: 0.02558   -   val_loss: 0.02229
# Epoch 4/50   -   loss: 0.02201   -   val_loss: 0.02100
# Epoch 5/50   -   loss: 0.02054   -   val_loss: 0.01996
# Epoch 6/50   -   loss: 0.01974   -   val_loss: 0.02014
# Epoch 7/50   -   loss: 0.01925   -   val_loss: 0.01889
# Epoch 8/50   -   loss: 0.01864   -   val_loss: 0.01869
# Epoch 9/50   -   loss: 0.01806   -   val_loss: 0.01835
# Epoch 10/50   -   loss: 0.01777   -   val_loss: 0.01865
# Epoch 11/50   -   loss: 0.01755   -   val_loss: 0.01802
# Epoch 12/50   -   loss: 0.01710   -   val_loss: 0.01797
# Epoch 13/50   -   loss: 0.01672   -   val_loss: 0.01786
# Epoch 14/50   -   loss: 0.01663   -   val_loss: 0.01791
# Epoch 15/50   -   loss: 0.01642   -   val_loss: 0.01780
# Epoch 16/50   -   loss: 0.01604   -   val_loss: 0.01793
# Epoch 17/50   -   loss: 0.01585   -   val_loss: 0.01786
# Epoch 18/50   -   loss: 0.01587   -   val_loss: 0.01779
# Epoch 19/50   -   loss: 0.01551   -   val_loss: 0.01771
# Epoch 20/50   -   loss: 0.01535   -   val_loss: 0.01779
# Epoch 21/50   -   loss: 0.01516   -   val_loss: 0.01769
# Epoch 22/50   -   loss: 0.01500   -   val_loss: 0.01779
# Epoch 23/50   -   loss: 0.01484   -   val_loss: 0.01783
# Epoch 24/50   -   loss: 0.01476   -   val_loss: 0.01774
# Epoch 25/50   -   loss: 0.01471   -   val_loss: 0.01773
# Epoch    25: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 26/50   -   loss: 0.01393   -   val_loss: 0.01764
# Epoch 27/50   -   loss: 0.01359   -   val_loss: 0.01762
# Epoch 28/50   -   loss: 0.01343   -   val_loss: 0.01764
# Epoch 29/50   -   loss: 0.01319   -   val_loss: 0.01766
# Epoch 30/50   -   loss: 0.01313   -   val_loss: 0.01765
# Epoch 31/50   -   loss: 0.01298   -   val_loss: 0.01766
# Epoch 32/50   -   loss: 0.01281   -   val_loss: 0.01769
# Epoch 33/50   -   loss: 0.01274   -   val_loss: 0.01769
# Epoch 34/50   -   loss: 0.01262   -   val_loss: 0.01772
# Epoch 35/50   -   loss: 0.01246   -   val_loss: 0.01772
# Epoch 36/50   -   loss: 0.01236   -   val_loss: 0.01774
# Epoch 37/50   -   loss: 0.01227   -   val_loss: 0.01775
# Epoch 38/50   -   loss: 0.01222   -   val_loss: 0.01780
# Epoch 39/50   -   loss: 0.01205   -   val_loss: 0.01781
# Epoch 40/50   -   loss: 0.01194   -   val_loss: 0.01780
# Epoch 41/50   -   loss: 0.01186   -   val_loss: 0.01785
# Epoch 42/50   -   loss: 0.01178   -   val_loss: 0.01790
# Epoch 43/50   -   loss: 0.01163   -   val_loss: 0.01782
# Epoch 44/50   -   loss: 0.01153   -   val_loss: 0.01787
# Epoch 45/50   -   loss: 0.01144   -   val_loss: 0.01790
# Epoch 46/50   -   loss: 0.01128   -   val_loss: 0.01796
# Epoch 47/50   -   loss: 0.01125   -   val_loss: 0.01796
# Epoch 48/50   -   loss: 0.01113   -   val_loss: 0.01794
# Epoch 49/50   -   loss: 0.01098   -   val_loss: 0.01797
# Epoch 50/50   -   loss: 0.01091   -   val_loss: 0.01802
# Epoch 1/50   -   loss: 0.37978   -   val_loss: 0.06974
# Epoch 2/50   -   loss: 0.04291   -   val_loss: 0.02710
# Epoch 3/50   -   loss: 0.02573   -   val_loss: 0.02144
# Epoch 4/50   -   loss: 0.02230   -   val_loss: 0.02042
# Epoch 5/50   -   loss: 0.02079   -   val_loss: 0.01901
# Epoch 6/50   -   loss: 0.01979   -   val_loss: 0.01836
# Epoch 7/50   -   loss: 0.01910   -   val_loss: 0.01778
# Epoch 8/50   -   loss: 0.01865   -   val_loss: 0.01766
# Epoch 9/50   -   loss: 0.01819   -   val_loss: 0.01727
# Epoch 10/50   -   loss: 0.01793   -   val_loss: 0.01726
# Epoch 11/50   -   loss: 0.01760   -   val_loss: 0.01715
# Epoch 12/50   -   loss: 0.01727   -   val_loss: 0.01693
# Epoch 13/50   -   loss: 0.01702   -   val_loss: 0.01703
# Epoch 14/50   -   loss: 0.01673   -   val_loss: 0.01673
# Epoch 15/50   -   loss: 0.01652   -   val_loss: 0.01679
# Epoch 16/50   -   loss: 0.01624   -   val_loss: 0.01670
# Epoch 17/50   -   loss: 0.01600   -   val_loss: 0.01676
# Epoch 18/50   -   loss: 0.01584   -   val_loss: 0.01662
# Epoch 19/50   -   loss: 0.01562   -   val_loss: 0.01665
# Epoch 20/50   -   loss: 0.01539   -   val_loss: 0.01662
# Epoch 21/50   -   loss: 0.01521   -   val_loss: 0.01670
# Epoch 22/50   -   loss: 0.01516   -   val_loss: 0.01661
# Epoch 23/50   -   loss: 0.01501   -   val_loss: 0.01669
# Epoch 24/50   -   loss: 0.01489   -   val_loss: 0.01657
# Epoch 25/50   -   loss: 0.01465   -   val_loss: 0.01663
# Epoch 26/50   -   loss: 0.01459   -   val_loss: 0.01683
# Epoch 27/50   -   loss: 0.01453   -   val_loss: 0.01668
# Epoch 28/50   -   loss: 0.01448   -   val_loss: 0.01680
# Epoch    28: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 29/50   -   loss: 0.01364   -   val_loss: 0.01660
# Epoch 30/50   -   loss: 0.01341   -   val_loss: 0.01655
# Epoch 31/50   -   loss: 0.01309   -   val_loss: 0.01655
# Epoch 32/50   -   loss: 0.01293   -   val_loss: 0.01655
# Epoch 33/50   -   loss: 0.01281   -   val_loss: 0.01659
# Epoch 34/50   -   loss: 0.01266   -   val_loss: 0.01659
# Epoch 35/50   -   loss: 0.01253   -   val_loss: 0.01660
# Epoch 36/50   -   loss: 0.01243   -   val_loss: 0.01665
# Epoch 37/50   -   loss: 0.01227   -   val_loss: 0.01664
# Epoch 38/50   -   loss: 0.01219   -   val_loss: 0.01667
# Epoch 39/50   -   loss: 0.01204   -   val_loss: 0.01669
# Epoch 40/50   -   loss: 0.01196   -   val_loss: 0.01672
# Epoch 41/50   -   loss: 0.01188   -   val_loss: 0.01673
# Epoch 42/50   -   loss: 0.01172   -   val_loss: 0.01678
# Epoch 43/50   -   loss: 0.01159   -   val_loss: 0.01678
# Epoch 44/50   -   loss: 0.01148   -   val_loss: 0.01682
# Epoch 45/50   -   loss: 0.01140   -   val_loss: 0.01680
# Epoch 46/50   -   loss: 0.01133   -   val_loss: 0.01684
# Epoch 47/50   -   loss: 0.01121   -   val_loss: 0.01685
# Epoch 48/50   -   loss: 0.01105   -   val_loss: 0.01688
# Epoch 49/50   -   loss: 0.01098   -   val_loss: 0.01689
# Epoch 50/50   -   loss: 0.01087   -   val_loss: 0.01687
# Epoch 1/50   -   loss: 0.37702   -   val_loss: 0.06633
# Epoch 2/50   -   loss: 0.04294   -   val_loss: 0.02838
# Epoch 3/50   -   loss: 0.02571   -   val_loss: 0.02210
# Epoch 4/50   -   loss: 0.02249   -   val_loss: 0.02142
# Epoch 5/50   -   loss: 0.02078   -   val_loss: 0.02006
# Epoch 6/50   -   loss: 0.01969   -   val_loss: 0.01949
# Epoch 7/50   -   loss: 0.01932   -   val_loss: 0.01925
# Epoch 8/50   -   loss: 0.01869   -   val_loss: 0.01885
# Epoch 9/50   -   loss: 0.01821   -   val_loss: 0.01852
# Epoch 10/50   -   loss: 0.01795   -   val_loss: 0.01837
# Epoch 11/50   -   loss: 0.01756   -   val_loss: 0.01827
# Epoch 12/50   -   loss: 0.01725   -   val_loss: 0.01828
# Epoch 13/50   -   loss: 0.01699   -   val_loss: 0.01806
# Epoch 14/50   -   loss: 0.01674   -   val_loss: 0.01807
# Epoch 15/50   -   loss: 0.01647   -   val_loss: 0.01788
# Epoch 16/50   -   loss: 0.01619   -   val_loss: 0.01790
# Epoch 17/50   -   loss: 0.01612   -   val_loss: 0.01799
# Epoch 18/50   -   loss: 0.01580   -   val_loss: 0.01782
# Epoch 19/50   -   loss: 0.01559   -   val_loss: 0.01780
# Epoch 20/50   -   loss: 0.01560   -   val_loss: 0.01775
# Epoch 21/50   -   loss: 0.01535   -   val_loss: 0.01780
# Epoch 22/50   -   loss: 0.01510   -   val_loss: 0.01772
# Epoch 23/50   -   loss: 0.01509   -   val_loss: 0.01779
# Epoch 24/50   -   loss: 0.01488   -   val_loss: 0.01777
# Epoch 25/50   -   loss: 0.01480   -   val_loss: 0.01780
# Epoch 26/50   -   loss: 0.01469   -   val_loss: 0.01787
# Epoch    26: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 27/50   -   loss: 0.01397   -   val_loss: 0.01771
# Epoch 28/50   -   loss: 0.01368   -   val_loss: 0.01767
# Epoch 29/50   -   loss: 0.01351   -   val_loss: 0.01769
# Epoch 30/50   -   loss: 0.01330   -   val_loss: 0.01771
# Epoch 31/50   -   loss: 0.01324   -   val_loss: 0.01771
# Epoch 32/50   -   loss: 0.01309   -   val_loss: 0.01774
# Epoch 33/50   -   loss: 0.01299   -   val_loss: 0.01774
# Epoch 34/50   -   loss: 0.01289   -   val_loss: 0.01772
# Epoch 35/50   -   loss: 0.01277   -   val_loss: 0.01777
# Epoch 36/50   -   loss: 0.01261   -   val_loss: 0.01775
# Epoch 37/50   -   loss: 0.01253   -   val_loss: 0.01777
# Epoch 38/50   -   loss: 0.01246   -   val_loss: 0.01784
# Epoch 39/50   -   loss: 0.01233   -   val_loss: 0.01787
# Epoch 40/50   -   loss: 0.01229   -   val_loss: 0.01783
# Epoch 41/50   -   loss: 0.01216   -   val_loss: 0.01787
# Epoch 42/50   -   loss: 0.01200   -   val_loss: 0.01795
# Epoch 43/50   -   loss: 0.01191   -   val_loss: 0.01798
# Epoch 44/50   -   loss: 0.01187   -   val_loss: 0.01799
# Epoch 45/50   -   loss: 0.01177   -   val_loss: 0.01804
# Epoch 46/50   -   loss: 0.01169   -   val_loss: 0.01804
# Epoch 47/50   -   loss: 0.01166   -   val_loss: 0.01805
# Epoch 48/50   -   loss: 0.01149   -   val_loss: 0.01801
# Epoch 49/50   -   loss: 0.01136   -   val_loss: 0.01811
# Epoch 50/50   -   loss: 0.01134   -   val_loss: 0.01816
# Epoch 1/50   -   loss: 0.37865   -   val_loss: 0.07430
# Epoch 2/50   -   loss: 0.04345   -   val_loss: 0.02722
# Epoch 3/50   -   loss: 0.02553   -   val_loss: 0.02188
# Epoch 4/50   -   loss: 0.02264   -   val_loss: 0.02089
# Epoch 5/50   -   loss: 0.02117   -   val_loss: 0.01933
# Epoch 6/50   -   loss: 0.01978   -   val_loss: 0.01884
# Epoch 7/50   -   loss: 0.01917   -   val_loss: 0.01842
# Epoch 8/50   -   loss: 0.01869   -   val_loss: 0.01809
# Epoch 9/50   -   loss: 0.01825   -   val_loss: 0.01802
# Epoch 10/50   -   loss: 0.01801   -   val_loss: 0.01783
# Epoch 11/50   -   loss: 0.01772   -   val_loss: 0.01753
# Epoch 12/50   -   loss: 0.01734   -   val_loss: 0.01744
# Epoch 13/50   -   loss: 0.01696   -   val_loss: 0.01727
# Epoch 14/50   -   loss: 0.01666   -   val_loss: 0.01727
# Epoch 15/50   -   loss: 0.01646   -   val_loss: 0.01724
# Epoch 16/50   -   loss: 0.01633   -   val_loss: 0.01702
# Epoch 17/50   -   loss: 0.01606   -   val_loss: 0.01699
# Epoch 18/50   -   loss: 0.01578   -   val_loss: 0.01697
# Epoch 19/50   -   loss: 0.01574   -   val_loss: 0.01694
# Epoch 20/50   -   loss: 0.01555   -   val_loss: 0.01702
# Epoch 21/50   -   loss: 0.01531   -   val_loss: 0.01700
# Epoch 22/50   -   loss: 0.01519   -   val_loss: 0.01696
# Epoch 23/50   -   loss: 0.01505   -   val_loss: 0.01704
# Epoch    23: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 24/50   -   loss: 0.01432   -   val_loss: 0.01684
# Epoch 25/50   -   loss: 0.01406   -   val_loss: 0.01683
# Epoch 26/50   -   loss: 0.01386   -   val_loss: 0.01684
# Epoch 27/50   -   loss: 0.01375   -   val_loss: 0.01686
# Epoch 28/50   -   loss: 0.01356   -   val_loss: 0.01684
# Epoch 29/50   -   loss: 0.01343   -   val_loss: 0.01686
# Epoch 30/50   -   loss: 0.01333   -   val_loss: 0.01689
# Epoch 31/50   -   loss: 0.01321   -   val_loss: 0.01687
# Epoch 32/50   -   loss: 0.01311   -   val_loss: 0.01691
# Epoch 33/50   -   loss: 0.01297   -   val_loss: 0.01689
# Epoch 34/50   -   loss: 0.01287   -   val_loss: 0.01692
# Epoch 35/50   -   loss: 0.01277   -   val_loss: 0.01694
# Epoch 36/50   -   loss: 0.01264   -   val_loss: 0.01693
# Epoch 37/50   -   loss: 0.01259   -   val_loss: 0.01694
# Epoch 38/50   -   loss: 0.01244   -   val_loss: 0.01696
# Epoch 39/50   -   loss: 0.01233   -   val_loss: 0.01698
# Epoch 40/50   -   loss: 0.01226   -   val_loss: 0.01700
# Epoch 41/50   -   loss: 0.01215   -   val_loss: 0.01704
# Epoch 42/50   -   loss: 0.01202   -   val_loss: 0.01704
# Epoch 43/50   -   loss: 0.01193   -   val_loss: 0.01705
# Epoch 44/50   -   loss: 0.01182   -   val_loss: 0.01701
# Epoch 45/50   -   loss: 0.01171   -   val_loss: 0.01706
# Epoch 46/50   -   loss: 0.01168   -   val_loss: 0.01706
# Epoch 47/50   -   loss: 0.01155   -   val_loss: 0.01710
# Epoch 48/50   -   loss: 0.01137   -   val_loss: 0.01712
# Epoch 49/50   -   loss: 0.01128   -   val_loss: 0.01715
# Epoch 50/50   -   loss: 0.01125   -   val_loss: 0.01717
# Epoch 1/50   -   loss: 0.37844   -   val_loss: 0.07249
# Epoch 2/50   -   loss: 0.04278   -   val_loss: 0.02843
# Epoch 3/50   -   loss: 0.02555   -   val_loss: 0.02147
# Epoch 4/50   -   loss: 0.02204   -   val_loss: 0.02023
# Epoch 5/50   -   loss: 0.02052   -   val_loss: 0.01935
# Epoch 6/50   -   loss: 0.01974   -   val_loss: 0.01883
# Epoch 7/50   -   loss: 0.01895   -   val_loss: 0.01868
# Epoch 8/50   -   loss: 0.01865   -   val_loss: 0.01818
# Epoch 9/50   -   loss: 0.01811   -   val_loss: 0.01806
# Epoch 10/50   -   loss: 0.01766   -   val_loss: 0.01804
# Epoch 11/50   -   loss: 0.01745   -   val_loss: 0.01764
# Epoch 12/50   -   loss: 0.01711   -   val_loss: 0.01771
# Epoch 13/50   -   loss: 0.01681   -   val_loss: 0.01744
# Epoch 14/50   -   loss: 0.01646   -   val_loss: 0.01743
# Epoch 15/50   -   loss: 0.01617   -   val_loss: 0.01746
# Epoch 16/50   -   loss: 0.01596   -   val_loss: 0.01746
# Epoch 17/50   -   loss: 0.01573   -   val_loss: 0.01738
# Epoch 18/50   -   loss: 0.01558   -   val_loss: 0.01735
# Epoch 19/50   -   loss: 0.01531   -   val_loss: 0.01728
# Epoch 20/50   -   loss: 0.01518   -   val_loss: 0.01725
# Epoch 21/50   -   loss: 0.01503   -   val_loss: 0.01736
# Epoch 22/50   -   loss: 0.01491   -   val_loss: 0.01730
# Epoch 23/50   -   loss: 0.01476   -   val_loss: 0.01737
# Epoch 24/50   -   loss: 0.01463   -   val_loss: 0.01748
# Epoch    24: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 25/50   -   loss: 0.01397   -   val_loss: 0.01718
# Epoch 26/50   -   loss: 0.01369   -   val_loss: 0.01718
# Epoch 27/50   -   loss: 0.01348   -   val_loss: 0.01719
# Epoch 28/50   -   loss: 0.01331   -   val_loss: 0.01723
# Epoch 29/50   -   loss: 0.01314   -   val_loss: 0.01724
# Epoch 30/50   -   loss: 0.01304   -   val_loss: 0.01726
# Epoch 31/50   -   loss: 0.01290   -   val_loss: 0.01726
# Epoch 32/50   -   loss: 0.01287   -   val_loss: 0.01728
# Epoch 33/50   -   loss: 0.01266   -   val_loss: 0.01727
# Epoch 34/50   -   loss: 0.01260   -   val_loss: 0.01730
# Epoch 35/50   -   loss: 0.01251   -   val_loss: 0.01731
# Epoch 36/50   -   loss: 0.01236   -   val_loss: 0.01733
# Epoch 37/50   -   loss: 0.01231   -   val_loss: 0.01737
# Epoch 38/50   -   loss: 0.01214   -   val_loss: 0.01736
# Epoch 39/50   -   loss: 0.01204   -   val_loss: 0.01735
# Epoch 40/50   -   loss: 0.01194   -   val_loss: 0.01742
# Epoch 41/50   -   loss: 0.01185   -   val_loss: 0.01743
# Epoch 42/50   -   loss: 0.01170   -   val_loss: 0.01745
# Epoch 43/50   -   loss: 0.01159   -   val_loss: 0.01747
# Epoch 44/50   -   loss: 0.01148   -   val_loss: 0.01751
# Epoch 45/50   -   loss: 0.01141   -   val_loss: 0.01755
# Epoch 46/50   -   loss: 0.01127   -   val_loss: 0.01755
# Epoch 47/50   -   loss: 0.01120   -   val_loss: 0.01754
# Epoch 48/50   -   loss: 0.01103   -   val_loss: 0.01757
# Epoch 49/50   -   loss: 0.01096   -   val_loss: 0.01758
# Epoch 50/50   -   loss: 0.01085   -   val_loss: 0.01764

# %%
test_np = test_features.to_numpy()

oof = np.zeros((len(train_features.to_numpy()), N_STARTS, ntargets))
oof_targets = np.zeros((len(train_features.to_numpy()), ntargets))
preds = np.zeros((len(test_np), ntargets))

# %%
def mean_log_loss(y_true, y_pred):
    metrics = []
    worst_target = None
    worst_loss = 0.
    all_targets_ll = {}
    for i, target in enumerate(targets):
        _ll = log_loss(y_true[:, i], y_pred[:, i].astype(float), labels=[0,1])
        metrics.append(_ll)
        all_targets_ll[target] = _ll
        if _ll > worst_loss:
            worst_loss = _ll
            worst_target = target
    return np.mean(metrics), (worst_target, worst_loss), all_targets_ll

# %%
worst_targets_in_seed = []
all_targets_ll_in_seed = []
for seed in range(N_STARTS):
    print(f"Inference for seed {seed}")
    seed_targets = []
    seed_oof = []
    seed_preds = np.zeros((len(test_np), ntargets, N_FOLDS))
    
    for fold in range(N_FOLDS):
        # print(n, len(tr))
        tr_idx = folds_cv[seed] != fold
        te_idx = folds_cv[seed] == fold
        xval = train_features.to_numpy()[te_idx]
        yval = train_targets.to_numpy()[te_idx]
        fold_preds = []
        
        val_set = MoaDataset(xval, yval, top_feats)
        test_set = MoaDataset(test_np, None, top_feats, mode='test')
        
        dataloaders = {
            'val': DataLoader(val_set, batch_size=val_batch_size, shuffle=False),
            'test': DataLoader(test_set, batch_size=val_batch_size, shuffle=False)
        }
        
        checkpoint_path = f'repeat:{seed}_Fold:{fold+1}.pt'
        model = MoaModel(len(top_feats)).to(device)
        model.load_state_dict(torch.load(checkpoint_path))
        model.eval()
        
        for phase in ['val', 'test']:
            for i, (x, y) in enumerate(dataloaders[phase]):
                # print(i)
                if phase == 'val':
                    x, y = x.to(device), y.to(device)
                elif phase == 'test':
                    x = x.to(device)
                
                with torch.no_grad():
                    batch_preds = model(x)
                    
                    if phase == 'val':
                        seed_targets.append(y)
                        seed_oof.append(batch_preds)
                        # print(y_pred_lr.shape)
                    elif phase == 'test':
                        fold_preds.append(batch_preds)
                    
        fold_preds = torch.cat(fold_preds, dim=0).cpu().numpy()
        seed_preds[:, :, fold] = fold_preds
        
    seed_targets = torch.cat(seed_targets, dim=0).cpu().numpy()
    seed_oof = torch.cat(seed_oof, dim=0).cpu().numpy()
    seed_preds = np.mean(seed_preds, axis=2)
    
    print("Score for this seed {:5.5f}".format(mean_log_loss(seed_targets, seed_oof)[0]))
    worst_targets_in_seed.append(mean_log_loss(seed_targets, seed_oof)[1])
    all_targets_ll_in_seed.append(mean_log_loss(seed_targets, seed_oof)[2])
    oof_targets = seed_targets
    oof[:, seed, :] = seed_oof
    preds += seed_preds / N_STARTS

oof = np.mean(oof, axis=1)
print("Overall score is {:5.5f}".format(mean_log_loss(oof_targets, oof)[0]))
# Out:
# Inference for seed 0
# Score for this seed 0.01731
# Inference for seed 1
# Score for this seed 0.01727
# Inference for seed 2
# Score for this seed 0.01733
# Inference for seed 3
# Score for this seed 0.01733
# Inference for seed 4
# Score for this seed 0.01732
# Overall score is 0.01980

# %%
ss[targets] = preds
ss.loc[test_features['cp_type']== 1, targets] = 0
ss.to_csv('submission.csv', index=False)
